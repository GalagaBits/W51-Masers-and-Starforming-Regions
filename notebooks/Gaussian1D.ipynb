# %%
import pyspeckit
from spectral_cube import SpectralCube
from astropy import units as u

import pylab as pl
pl.style.use('default')

# %%
cd /Volumes/GalagaResearch/Developer/masers/W51/FITS
# Out:
# /Volumes/GalagaResearch/Developer/masers/W51/FITS

# %% [markdown]
# # (7,6)

# %%
cube = SpectralCube.read('W51North_spw_6_corrected11_1_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 215, 144

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=22.92075 * u.GHz, xmax=22.92175 * u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 22.92126, 0.00001, 0.3, 22.92115, 0.00001, 0.3, 22.9210, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.5, 22.92126, 0.00001, 0.3, 22.92115, 0.00001, 0.3, 22.9210, 0.00001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.364512 +/-      0.00579124 ,
#  Param #1       SHIFT0 =      22.9213 +/-     6.06696e-07 ,
#  Param #2       WIDTH0 =   3.1155e-05 +/-     6.33182e-07   Range:   [0,inf),
#  Param #3   AMPLITUDE1 =     0.251165 +/-       0.0052547 ,
#  Param #4       SHIFT1 =      22.9212 +/-     9.95985e-07 ,
#  Param #5       WIDTH1 =  3.99334e-05 +/-     1.13752e-06   Range:   [0,inf),
#  Param #6   AMPLITUDE2 =     0.235693 +/-       0.0057826 ,
#  Param #7       SHIFT2 =       22.921 +/-     9.07868e-07 ,
#  Param #8       WIDTH2 =  3.11759e-05 +/-     9.38068e-07   Range:   [0,inf)]

# %% [markdown]
# # (7,7)

# %%
cube = SpectralCube.read('W51North_spw_28_corrected31_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 215, 144

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=25.7106 * u.GHz, xmax=25.7116 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 25.710947, 0.0001, 0.1, 25.711088, 0.0001, 0.1, 25.711229, 0.0001], linewidth=1.5)
sp.specfit(guesses=[0.1, 25.710947, 0.0001, 0.1, 25.711088, 0.0001, 0.1, 25.711229, 0.0001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0433099 +/-      0.00595585 ,
#  Param #1       SHIFT0 =      25.7109 +/-     1.06829e-05 ,
#  Param #2       WIDTH0 =  6.19456e-05 +/-     1.18443e-05   Range:   [0,inf),
#  Param #3   AMPLITUDE1 =     0.550128 +/-       0.0085671 ,
#  Param #4       SHIFT1 =      25.7111 +/-     6.77568e-07 ,
#  Param #5       WIDTH1 =  3.00142e-05 +/-     7.22809e-07   Range:   [0,inf),
#  Param #6   AMPLITUDE2 =     0.227833 +/-      0.00661861 ,
#  Param #7       SHIFT2 =      25.7112 +/-     2.04631e-06 ,
#  Param #8       WIDTH2 =  5.05774e-05 +/-     2.25827e-06   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 413, 407

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=21.0660 * u.GHz, xmax=21.0670 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.0664, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.0664, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0833964 +/-      0.00509543 ,
#  Param #1       SHIFT0 =      21.0664 +/-     1.35983e-06 ,
#  Param #2       WIDTH0 =  1.92728e-05 +/-     1.35967e-06   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 397, 365

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=21.0660 * u.GHz, xmax=21.0670 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.0664, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.0664, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0376121 +/-      0.00501444 ,
#  Param #1       SHIFT0 =      21.0665 +/-     3.56802e-06 ,
#  Param #2       WIDTH0 =  2.31775e-05 +/-     3.56794e-06   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 415, 344

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=21.0670 * u.GHz, xmax=21.0680 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.0674, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.0674, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.416496 +/-      0.00863173 ,
#  Param #1       SHIFT0 =      21.0674 +/-     7.01564e-07 ,
#  Param #2       WIDTH0 =  2.93161e-05 +/-     7.01554e-07   Range:   [0,inf)]

# %% [markdown]
# # (5,3)

# %%
cube = SpectralCube.read('W51North_spw_44_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 356, 638

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=21.2805 * u.GHz, xmax=21.282 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.2813, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.2813, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.458479 +/-      0.00585162 ,
#  Param #1       SHIFT0 =      21.2813 +/-     2.60244e-07 ,
#  Param #2       WIDTH0 =  1.76505e-05 +/-     2.59994e-07   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_44_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 630

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=21.2805 * u.GHz, xmax=21.282 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.2813, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.2813, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0782895 +/-      0.00516538 ,
#  Param #1       SHIFT0 =      21.2814 +/-     1.74204e-06 ,
#  Param #2       WIDTH0 =  2.28652e-05 +/-       1.742e-06   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_50_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 359, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=18.8805 * u.GHz, xmax=18.882 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 18.8813, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 18.8813, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0390231 +/-       0.0022983 ,
#  Param #1       SHIFT0 =      18.8813 +/-     2.28896e-06 ,
#  Param #2       WIDTH0 =  3.36571e-05 +/-     2.28894e-06   Range:   [0,inf)]

# %% [markdown]
# # (6,3)

# %%
cube = SpectralCube.read('W51North_spw_56_corrected_40_aug_02.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 356, 638

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=19.753 * u.GHz, xmax=19.755 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 19.754, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 19.754, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =      0.86066 +/-      0.00371696 ,
#  Param #1       SHIFT0 =      19.7539 +/-     8.45461e-08 ,
#  Param #2       WIDTH0 =   1.6956e-05 +/-     8.45737e-08   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_56_corrected_40_aug_02.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 630

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=19.753 * u.GHz, xmax=19.755 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 19.754, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 19.754, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.148111 +/-      0.00628706 ,
#  Param #1       SHIFT0 =       19.754 +/-     8.22665e-07 ,
#  Param #2       WIDTH0 =  1.67826e-05 +/-     8.22585e-07   Range:   [0,inf)]

# %% [markdown]
# # (7,4)

# %%
cube = SpectralCube.read('W51North_spw_53_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=19.214 * u.GHz, xmax=19.216 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 19.215, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 19.215, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =    0.0467692 +/-      0.00325754 ,
#  Param #1       SHIFT0 =       19.215 +/-     2.07416e-06 ,
#  Param #2       WIDTH0 =  2.57885e-05 +/-     2.07413e-06   Range:   [0,inf)]

# %% [markdown]
# # (7,5)

# %%
cube = SpectralCube.read('W51North_spw_38_corrected6_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=20.8006 * u.GHz, xmax=20.8016 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 20.8011, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 20.8011, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =      2.45816 +/-       0.0269085 ,
#  Param #1       SHIFT0 =      20.8011 +/-     3.58537e-07 ,
#  Param #2       WIDTH0 =  2.83654e-05 +/-     3.58532e-07   Range:   [0,inf)]

# %%
cube = SpectralCube.read('W51North_spw_48_corrected2_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=18.804 * u.GHz, xmax=18.8054 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 18.8051, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 18.8051, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.112321 +/-      0.00326212 ,
#  Param #1       SHIFT0 =      18.8051 +/-     6.70049e-07 ,
#  Param #2       WIDTH0 =  1.99794e-05 +/-     6.70026e-07   Range:   [0,inf)]

# %% [markdown]
# # (9,8)

# %%
cube = SpectralCube.read('W51North_spw_8_corrected21_aug_02_ICRS.fits', format='fits')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=23.652 * u.GHz, xmax=23.654 * u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 23.6532, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 23.6532, 0.0001,], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
sp.specfit.parinfo
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# [Param #0   AMPLITUDE0 =     0.175801 +/-      0.00534233 ,
#  Param #1       SHIFT0 =      23.6532 +/-     7.18386e-07 ,
#  Param #2       WIDTH0 =  2.04729e-05 +/-     7.18352e-07   Range:   [0,inf)]
