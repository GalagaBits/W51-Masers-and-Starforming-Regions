# %% [markdown]
# # Gaussian Fit for 1-Dimensional Spectra | Version 2.0

# %%
# Out:
# /orange/adamginsburg/w51/vla/19A-254/derod/W51_Kband_2019_08_12

# %%
import pyspeckit
from spectral_cube import SpectralCube
from astropy import units as u

import pylab as pl
pl.style.use('default')

# %% [markdown]
# ##  NH3(7,6) spw06

# %%
cube = SpectralCube.read('W51North_spw_06_2019_08_12_01.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 615, 544

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=22.92075 * u.GHz, xmax=22.92175 * u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 22.92126, 0.00001, 0.3, 22.92115, 0.00001, 0.3, 22.9210, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.5, 22.92126, 0.00001, 0.3, 22.92115, 0.00001, 0.3, 22.9210, 0.00001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
# pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_07_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 952, 261

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))
sp.plotter(color='black', xmin=23.096*u.GHz, xmax=23.099*u.GHz, figure=fig)

sp.specfit(guesses=[0.075, 23.0976, 0.1,], linewidth=1.5)
sp.specfit(guesses=[0.075, 23.0976, 0.1,], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
#pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16 )

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw8

# %%
cube = SpectralCube.read('W51North_spw_08_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 558, 837

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))

sp.plotter(color='black', xmin=23.652*u.GHz, xmax=23.654*u.GHz, figure=fig)

sp.specfit(guesses=[0.2, 23.653, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.2, 23.653, 0.00001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
#pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16 )

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw15

# %%
cube = SpectralCube.read('W51North_spw_15_2019_08_12_01.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 616, 543

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))

sp.plotter(color='black', xmin=24.200*u.GHz, xmax=24.202*u.GHz, figure=fig)

sp.specfit(guesses=[0.06, 24.2011, 0.00001, 0.06, 24.2015, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.06, 24.2011, 0.00001, 0.06, 24.2015, 0.00001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
#pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16 )

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_15_2019_08_12_01.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 615, 544

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(12,8))

sp.plotter(color='black', xmin=24.200*u.GHz, xmax=24.202*u.GHz, figure=fig)

sp.specfit(guesses=[0.06, 24.2011, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.06, 24.2011, 0.00001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

ax.set_xlabel(f"Frequency [GHz]", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
#pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16 )

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw21

# %%
cube = SpectralCube.read('W51North_spw_21_2019_08_12_01.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 542, 547

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=24.90*u.GHz, xmax=24.96*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 24.9281, 0.0001], linewidth=1.5)
sp.specfit(guesses=[0.1, 24.9281, 0.0001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw 22

# %%
cube = SpectralCube.read('W51North_spw_22_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 544, 616

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=25.0*u.GHz, xmax=25.1*u.GHz, figure=fig)

sp.specfit(guesses=[0.06, 25.051926, 0.001], linewidth=1.5)
sp.specfit(guesses=[0.06, 25.051926, 0.001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw27

# %%
cube = SpectralCube.read('W51North_spw_27_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 544, 615

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=25.70*u.GHz, xmax=25.72*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 25.71, 0.0001], linewidth=1.5)
sp.specfit(guesses=[0.1, 25.71, 0.0001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(7,7) spw28

# %%
cube = SpectralCube.read('W51North_spw_28_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 544, 615

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=25.71*u.GHz, xmax=25.7125*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 25.710947, 0.0001, 0.1, 25.711088, 0.0001, 0.1, 25.711229, 0.0001], linewidth=1.5)
sp.specfit(guesses=[0.1, 25.710947, 0.0001, 0.1, 25.711088, 0.0001, 0.1, 25.711229, 0.0001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_36_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 837, 558

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=20.78*u.GHz, xmax=20.82*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 20.801232, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.1, 20.801232, 0.0001,], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw 37

# %%
cube = SpectralCube.read('W51North_spw_37_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 834, 555

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=20.7305*u.GHz, xmax=20.7325*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 20.7313, 0.0008,], linewidth=1.5)
sp.specfit(guesses=[0.1, 20.7313, 0.0008,], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_37_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 837, 559

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=20.7305*u.GHz, xmax=20.7325*u.GHz, figure=fig)

sp.specfit(guesses=[0.025, 20.731415, 0.0000015,], linewidth=1.5)
sp.specfit(guesses=[0.025, 20.731415, 0.0000015,], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

# pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw40

# %%
cube = SpectralCube.read('W51North_spw_40_2019_08_12_01.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 544, 615

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=21.045*u.GHz, xmax=21.085*u.GHz, figure=fig)

sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)
sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw41

# %%
cube = SpectralCube.read('W51North_spw_41_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 607, 613

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=21.066*u.GHz, xmax=21.067*u.GHz, figure=fig)

sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)
sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_41_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 565, 597

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=21.066*u.GHz, xmax=21.067*u.GHz, figure=fig)

sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)
sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_41_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 544, 615

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=21.0665*u.GHz, xmax=21.068*u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 21.0674, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.5, 21.0674, 0.0001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw44

# %%
cube = SpectralCube.read('W51North_spw_44_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 838, 556

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=21.2805*u.GHz, xmax=21.282*u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 21.28125, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.5, 21.28125, 0.0001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw48

# %%
cube = SpectralCube.read('W51North_spw_48_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 836, 558

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=18.804*u.GHz, xmax=18.806*u.GHz, figure=fig)

sp.specfit(guesses=[0.14, 18.8051, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.14, 18.8051, 0.0001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# # spw 50

# %%
cube = SpectralCube.read('W51North_spw_50_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 837, 559

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=18.8805*u.GHz, xmax=18.882*u.GHz, figure=fig)

sp.specfit(guesses=[0.05, 18.8813, 0.00001,], linewidth=1.5)
sp.specfit(guesses=[0.05, 18.8813, 0.00001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw 53

# %%
cube = SpectralCube.read('W51North_spw_53_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 836, 559

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=19.214*u.GHz, xmax=19.216*u.GHz, figure=fig)

sp.specfit(guesses=[0.05, 19.215019, 0.000016,], linewidth=1.5)
sp.specfit(guesses=[0.05, 19.215019, 0.000016,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## spw55

# %%
cube = SpectralCube.read('W51North_spw_55_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)

# cube2 = SpectralCube.read('W51North_spw_55_2019_08_12_02.residual', format='casa_image')
# cube2 = cube2.with_spectral_unit(u.GHz)

# print(cube3)

x, y = 836, 556

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=19.74*u.GHz, xmax=19.76*u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 19.753442, 0.00001,], linewidth=1.5)
sp.specfit(guesses=[0.5, 19.753442, 0.00001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube[100].value
# Out:
# array([[ 3.8596886e-04,  1.1248973e-04, -8.9907953e-05, ...,
#          1.4878686e-03,  1.5285332e-03,  1.3822070e-03],
#        [ 8.5164531e-04,  5.7224149e-04,  3.1086773e-04, ...,
#          1.3749357e-03,  1.4625698e-03,  1.3675441e-03],
#        [ 1.0136424e-03,  7.9349492e-04,  5.6190952e-04, ...,
#          1.1406207e-03,  1.3327959e-03,  1.3535224e-03],
#        ...,
#        [-8.8696799e-04, -6.3734432e-04, -3.9353277e-04, ...,
#          3.4885097e-04,  1.9794646e-04,  3.6390531e-05],
#        [-7.4048963e-04, -5.8648520e-04, -4.0332961e-04, ...,
#          8.3345083e-05, -5.4952205e-05, -1.2942714e-04],
#        [-4.2689676e-04, -3.0666433e-04, -1.3798644e-04, ...,
#         -1.6268788e-04, -3.0090840e-04, -3.1589976e-04]], dtype=float32)

# %% [markdown]
# ## spw 56

# %%
cube = SpectralCube.read('W51North_spw_56_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 837, 556

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=19.753*u.GHz, xmax=19.7545*u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 19.753442, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.5, 19.753442, 0.0001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_56_2019_08_12_02.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 830, 558

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=19.753*u.GHz, xmax=19.7545*u.GHz, figure=fig)

sp.specfit(guesses=[0.5, 19.753442, 0.0001,], linewidth=1.5)
sp.specfit(guesses=[0.5, 19.753442, 0.0001,], linewidth=1.5)
#sp.specfit(guesses=[0.02, 21.0655, 0.001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)
