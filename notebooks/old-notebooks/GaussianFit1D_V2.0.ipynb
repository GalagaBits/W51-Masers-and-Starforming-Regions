# %% [markdown]
# # Gaussian Fit for 1-Dimensional Spectra | Version 2.0
# **Kband**
#
# Using corrected imaging for better Jy/beam measurments

# %%
cd /orange/adamginsburg/w51/vla/19A-254/derod/
# Out:
# /orange/adamginsburg/w51/vla/19A-254/derod

# %%
import pyspeckit
from spectral_cube import SpectralCube
from astropy import units as u

import pylab as pl
pl.style.use('default')

# %% [markdown]
# ## NH3(5,3) spw44

# %%
cube = SpectralCube.read('W51North_spw_44_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 356, 638

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=21.281*u.GHz, xmax=21.282*u.GHz, figure=fig)

sp.specfit(guesses=[0.35, 21.28125, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.35, 21.28125, 0.00001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

pl.title("NH3 (5,3)_1 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# /scratch/local/44726198/ipykernel_26542/1978965729.py in <module>
#       6 sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
#       7 fig = pl.figure(figsize=(12,8))
# ----> 8 sp.plotter(color='black', xmin=21.281*u.GHz, xmax=21.282*u.GHz, figure=fig)
#       9
#      10 sp.specfit(guesses=[0.35, 21.28125, 0.00001], linewidth=1.5)
#
# ...

# %%
cube = SpectralCube.read('W51North_spw_44_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 630

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=21.281*u.GHz, xmax=21.282*u.GHz, figure=fig)

sp.specfit(guesses=[0.1, 21.28141, 0.000001], linewidth=1.5)
sp.specfit(guesses=[0.1, 21.28141, 0.000001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

pl.title("NH3 (5,3)_2 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(6,2) spw50

# %%
cube = SpectralCube.read('W51North_spw_50_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 359, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=18.88*u.GHz, xmax=18.8815*u.GHz, figure=fig)

sp.specfit(guesses=[0.04, 18.88126, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.04, 18.88126, 0.00001], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (6,2) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(6,3) spw56

# %%
cube = SpectralCube.read('W51North_spw_56_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 359, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=19.7535*u.GHz, xmax=19.7545*u.GHz, figure=fig)

sp.specfit(guesses=[0.11, 19.7540, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.11, 19.7540, 0.00001], linewidth=1.5)



sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (6,3)_1 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_56_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 630

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=19.7535*u.GHz, xmax=19.7545*u.GHz, figure=fig)

sp.specfit(guesses=[0.11, 19.7540, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.11, 19.7540, 0.00001], linewidth=1.5)



sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (6,3)_2 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(7,4) spw53

# %%
cube = SpectralCube.read('W51North_spw_53_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=19.2145*u.GHz, xmax=19.2155*u.GHz, figure=fig)

sp.specfit(guesses=[0.05, 19.21503, 0.000001], linewidth=1.5)
sp.specfit(guesses=[0.05, 19.21503, 0.000001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (7,4) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_38_corrected6.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 637, 358

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=20.8006*u.GHz, xmax=20.8020*u.GHz, figure=fig)

sp.specfit(guesses=[2.5, 20.8011, 0.00001], linewidth=1.5)
sp.specfit(guesses=[2.5, 20.8011, 0.00001], linewidth=1.5)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (7,6) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(7,6) spw6

# %%
cube = SpectralCube.read('W51North_spw_6_corrected11_1.image', format='casa_image')
cube = cube.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 22.924940*u.GHz)
y, x = 215, 144
pl.rcParams['figure.dpi'] = 600
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig, ax = pl.subplots(figsize=(6,4))
ax = pl.subplot()


sp.plotter(color='black', xmin=44 * u.km/u.s, xmax=60 * u.km/u.s, figure=fig)

sp.specfit(guesses=[0.075, 48, 0.1, 0.06, 50, 0.1, 0.09, 52, 0.1], linewidth=1.5)
sp.specfit(guesses=[0.075, 48, 0.1, 0.06, 50, 0.1, 0.09, 52, 0.1], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)

ax.set_xlabel("$V_{LSR}$ (km s$^{-1}$)", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
pl.text(46, 0.39, "NH$_3$ (7,6)", fontsize = 16)

# sp.specfit.plotresiduals(color='black', zeroline=True)
# pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# Text(46, 0.39, 'NH$_3$ (7,6)')

# %% [markdown]
# ## NH3(7,7) spw28

# %%
cube = SpectralCube.read('W51North_spw_28_corrected31.image', format='casa_image')
cube = cube.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 25.715182*u.GHz)
y, x = 215, 144
pl.rcParams['figure.dpi'] = 600
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])

fig, ax = pl.subplots(figsize=(6,4))
ax = pl.subplot()

sp.plotter(color='black', xmin=30 * u.km/u.s, xmax=65 * u.km/u.s, figure=fig)

sp.specfit(guesses=[0.1, 50, 0.1, 0.5, 48, 0.1, 0.2, 46, 0.1], linewidth=1.5)
sp.specfit(guesses=[0.1, 50, 0.1, 0.5, 48, 0.1, 0.2, 46, 0.1], linewidth=1.5)

sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)
ax.set_xlabel("$V_{LSR}$ (km s$^{-1}$)", fontsize=16)
#ax.title("NH3 (7,7) Line", fontsize=16)
ax.set_ylabel(f"$S_\\nu$ (Jy)",fontsize=16)
pl.yticks(fontsize=16)
pl.xticks(fontsize=16)
pl.text(44, 0.6, "NH$_3$ (7,7)", fontsize = 16)
#ax.set_xticklabels(tick_labels.astype(int))
# sp.specfit.plotresiduals(color='black', zeroline=True)
# #ax.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# Text(44, 0.6, 'NH$_3$ (7,7)')

# %%
gs = fig.add_gridspec(3, hspace=0)
axs = gs.subplots(sharex=True, sharey=True)
fig.suptitle('Sharing both axes')
axs[0].plot(x, y ** 2)
axs[1].plot(x, 0.3 * y, 'o')
axs[2].plot(x, y, '+')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(9,9))

ax = pl.subplot(projection=ww)
cen = fh.shape[1]/2, fh.shape[2]/2
df = pd.read_csv('/orange/adamginsburg/w51/vla/19A-254/derod/W51-Masers-and-Starforming-Regions/notebooks/ammonia_radii.csv')

#im = ax.imshow(fh[0].data, cmap='gray', norm=visualization.simple_norm(fh[0].data, stretch='log', max_percent=100.00))
sc = ax.scatter(df.dec, df.ra, c=df.vlsr_kms, s=100*(df.S+1)**(3/4), cmap='jet',facecolors="None", edgecolors='black', transform=ax.get_transform('world'))
ax.scatter(2.909159082e+02, 1.451801029e+01, marker="x", c='black', linewidth=1.0, s=100, transform=ax.get_transform('world'))

w51north_settings()

cb = plt.colorbar(mappable=sc)
cb.set_label("$V_{LSR}$ [km s-1]", fontsize = 16)

ax.axis([cen[0]+355,cen[0]+395,cen[1]-45,cen[1]-5])


cb.ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## NH3(8,5) spw48

# %%
cube = SpectralCube.read('W51North_spw_48_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))



sp.plotter(color='black', xmin=18.8030*u.GHz, xmax=18.8059*u.GHz, figure=fig)

sp.specfit(guesses=[0.09, 18.8051, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.09, 18.8051, 0.00001], linewidth=1.5)




sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (8,5) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(9,8) spw8

# %%
cube = SpectralCube.read('W51North_spw_8_corrected21.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 358, 637

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=23.650*u.GHz, xmax=23.655*u.GHz, figure=fig)
sp.specfit(guesses=[0.13, 23.65319, 0.00001], linewidth=1)
sp.specfit(guesses=[0.13, 23.65319, 0.00001], linewidth=1)


sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (9,8) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# divide by zero encountered in long_scalars
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'title' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# support for accessing str attributes such as 'lower' from PhysicalType instances is deprecated since 4.3 and will be removed in a subsequent release.
# (-0.05, 0.05)

# %% [markdown]
# ## NH3(11,9) spw41

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
y, x = 413, 407

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=21.066*u.GHz, xmax=21.068*u.GHz, figure=fig)

sp.specfit(guesses=[0.35, 21.0664, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.35, 21.0664, 0.00001], linewidth=1.5)



sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (11,9) Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 365, 397

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=21.0655*u.GHz, xmax=21.067*u.GHz, figure=fig)

sp.specfit(guesses=[0.35, 21.0664, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.35, 21.0664, 0.00001], linewidth=1.5)



sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (11,9)_2 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)

# %%
cube = SpectralCube.read('W51North_spw_41_corrected2.image', format='casa_image')
cube = cube.with_spectral_unit(u.GHz)
x, y = 344, 415

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=21.0655*u.GHz, xmax=21.069*u.GHz, figure=fig)

sp.specfit(guesses=[0.35, 21.0675, 0.00001], linewidth=1.5)
sp.specfit(guesses=[0.35, 21.0675, 0.00001], linewidth=1.5)



sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=False)

pl.title("NH3 (11,9)_3 Line", fontsize=16)
pl.ylabel(f"$S_\\nu$ [Jy beam-1]",fontsize=16)
pl.xlabel(f"Frequency [GHz]",fontsize=16)
pl.xticks(fontsize=16)
pl.yticks(fontsize=16)

sp.specfit.plotresiduals(color='black', zeroline=True)
pl.ylim(-0.05, 0.05)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# (-0.05, 0.05)
