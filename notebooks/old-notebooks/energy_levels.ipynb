# %%
# !pip install git+https://github.com/giacomomarchioro/PyEnergyDiagrams
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -lue-core (/blue/adamginsburg/adamginsburg/miniconda3/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -lue-core (/blue/adamginsburg/adamginsburg/miniconda3/lib/python3.7/site-packages)
# ...
#   Cloning https://github.com/giacomomarchioro/PyEnergyDiagrams to /tmp/pip-req-build-8hefxlk3
#   Running command git clone --quiet https://github.com/giacomomarchioro/PyEnergyDiagrams /tmp/pip-req-build-8hefxlk3
#   Resolved https://github.com/giacomomarchioro/PyEnergyDiagrams to commit 3d6086564aa99aa0a0f3db4a510b736015562d5c
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for energydiagram: filename=energydiagram-0.2.0-py3-none-any.whl size=9465 sha256=4e5cf2a1178c7c0d7165e535f37b2b902a3461f009f4729218b198f7f508dac0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x_yuf6rc/wheels/9b/82/ff/7225b3cd5883ecb934746eec0dfa87457ae95010e545eab89c
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 400
plt.rcParams['savefig.dpi'] = 400

from energydiagram import ED


diagram = ED()

# Detected maser transistions (red)


diagram.add_level(23.3,'(1,1)',)
diagram.add_level(81.6,'(2,1)','l')
diagram.add_level(280.9,'(4,1)','l')
diagram.add_level(423.3,'(5,1)','l')
diagram.add_level(594.0,'(6,1)','l')

diagram.add_level(64.5,'(2,2)',)
diagram.add_level(150.2,'(3,2)','l')
diagram.add_level(265.0,'(4,2)','l')
diagram.add_level(407.5,'(5,2)','l')
diagram.add_level(578,'(6,2)','l',color='red')




diagram.add_level(123.5,'(3,3)')
diagram.add_level(238.4,'(4,3)','l')
diagram.add_level(340,'(5,3)','l',color='red')
diagram.add_level(551,'(6,3)','l',color='red')
diagram.add_level(750.8,'(7,3)','l')



diagram.add_level(200.5,'(4,4)',)
diagram.add_level(343.9,'(5,4)','l')
diagram.add_level(514.9,'(6,4)','l')
diagram.add_level(713,'(7,4)','l',color='red')



diagram.add_level(467.2,'(6,5)',)
diagram.add_level(666,'(7,5)','l',color='red')
diagram.add_level(893,'(8,5)','l',color='red')



diagram.add_level(408.06,'(6,6)',)
diagram.add_level(608,'(7,6)','l',color='green')
diagram.add_level(836.0,'(8,6)','l')
diagram.add_level(1090.9,'(9,6)','l')



diagram.add_level(539,'(7,7)',color='green')
diagram.add_level(767.3,'(8,7)','l')
diagram.add_level(1023.2,'(9,7)','l')
diagram.add_level(1306.1,'(10,7)','l')

diagram.add_level(943,'(9,8)',color='red')
diagram.add_level(1227.4,'(10,8)','l')


diagram.add_level(1137.6,'(10,9)',)
diagram.add_level(1450,'(11,9)','l',color='green')

## Other transitions from Zhang 2022

# %%
fig, ax = plt.subplots(figsize=(8,10))

diagram.plot(ylabel="$E_U$ (K)",ax = fig.gca()) # this is the default ylabel
diagram.offset = 1
# diagram.ax.axes.get_xaxis().set_visible(True)
# diagram.ax.spines['bottom'].set_visible(True)
diagram.fig.set_figwidth(10)
diagram.ax.set_xlabel(f'$K$')
diagram.fig.show()
# Out:
# /apps/python3/3.6.5/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
