# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
from astropy.time import Time
import numpy as np

plt.rcParams['figure.dpi'] = 400
plt.rcParams['savefig.dpi'] = 400

# %%
df = pd.read_csv('/orange/adamginsburg/w51/vla/19A-254/derod/W51-Masers-and-Starforming-Regions/notebooks/ammonia_Total.csv')

# %%
epoch = '2019-08-02T00:00:00'
t = Time(epoch,format='isot',scale='utc')

# %%
df['epoch'] = t
df['epoch_year'] = t.decimalyear

# %%
from astropy.table import Table
tbl = Table.read('w51d.tex', format='latex')[2:]

epoch_2 = tbl['Epoch']

# for x in epoch_2:
epoch_2 = Time(epoch_2,format='isot',scale='utc')
epoch_2
# Out:
# <Time object: scale='utc' format='isot' value=['2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2008-10-25T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2008-10-25T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-05T00:00:00.000' '2012-04-05T00:00:00.000'
#  '2012-04-05T00:00:00.000' '2012-04-05T00:00:00.000'
#  '2012-04-07T00:00:00.000' '2012-04-07T00:00:00.000'
#  '2012-04-07T00:00:00.000' '2008-10-23T00:00:00.000'
#  '2008-10-23T00:00:00.000' '2008-10-25T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '1995-11-28T00:00:00.000'
#  '1995-11-28T00:00:00.000' '1995-12-19T00:00:00.000'
#  '2011-08-31T00:00:00.000' '2012-04-04T00:00:00.000'
#  '2012-04-04T00:00:00.000' '1995-11-28T00:00:00.000'
#  '1995-11-28T00:00:00.000' '1995-12-19T00:00:00.000'
#  '2011-08-31T00:00:00.000' '2011-08-31T00:00:00.000']>

# %%
VLS = list(tbl['VLSR'])
VLSR = []
for x in VLS:
    VLSR.append(float(x))
        
VLSR
# Out:
# /scratch/local/57040925/ipykernel_130013/1886098388.py:4: UserWarning: Warning: converting a masked element to nan.
#   VLSR.append(float(x))
# [54.39,
#  57.01,
#  56.5,
#  57.0,
#  54.74,
#  54.44,
#  54.3,
#  45.72,
#  47.22,
#  46.02,
#  47.55,
#  45.92,
#  52.25,
#  54.37,
#  56.8,
#  61.23,
#  54.28,
#  56.59,
#  60.97,
#  45.6,
#  46.08,
#  45.66,
#  47.29,
#  49.92,
#  54.72,
#  54.34,
#  54.72,
#  43.76,
#  43.79,
#  43.63,
#  46.81,
#  46.06,
#  47.12,
#  43.84,
#  44.3,
#  44.39,
#  46.87,
#  nan]

# %%
S_flux = list(tbl['$S$'])
S = []
for x in S_flux:
    S.append(float(x))
        
S
# Out:
# /scratch/local/57040925/ipykernel_130013/1638628391.py:4: UserWarning: Warning: converting a masked element to nan.
#   S.append(float(x))
# [0.22,
#  0.3,
#  0.35,
#  0.52,
#  0.09,
#  3.1,
#  0.14,
#  6.2,
#  5.3,
#  1.95,
#  2.0,
#  1.29,
#  0.8,
#  6.8,
#  3.75,
#  1.15,
#  7.8,
#  4.9,
#  1.1,
#  1.7,
#  2.48,
#  2.27,
#  0.2,
#  0.18,
#  0.08,
#  0.03,
#  0.22,
#  0.16,
#  0.15,
#  0.12,
#  0.07,
#  0.34,
#  1.24,
#  0.14,
#  0.12,
#  0.1,
#  0.6,
#  nan]

# %%
epochd2 = []
epochd2 = np.append(epochd2,(df.epoch_year[0],
df.epoch_year[1],
df.epoch_year[2],
df.epoch_year[3],
df.epoch_year[4],
df.epoch_year[5],
df.epoch_year[6],
df.epoch_year[14],
epoch_2.decimalyear[1],
epoch_2.decimalyear[0],
epoch_2.decimalyear[2],
epoch_2.decimalyear[4],
epoch_2.decimalyear[5],
epoch_2.decimalyear[26]))

VLSRd2 = []
VLSRd2 = np.append(VLSRd2,(df.vlsr_kms[0],
df.vlsr_kms[1],
df.vlsr_kms[2],
df.vlsr_kms[3],
df.vlsr_kms[4],
df.vlsr_kms[5],
df.vlsr_kms[6],
df.vlsr_kms[14],
VLSR[1],
VLSR[0],
VLSR[2],
VLSR[4],
VLSR[5],
VLSR[26]))

# %%
import numpy as np
lineyear = []
linevlsr = []
lineyear.append(df.epoch_year[13])
linevlsr.append(df.vlsr_kms[13])
lineyear.append(epoch_2.decimalyear[6])
linevlsr.append(VLSR[6])
line_85 = np.column_stack((lineyear, linevlsr))

lineyear53 = []
linevlsr53 = []
lineyear53.append(df.epoch_year[0])
linevlsr53.append(df.vlsr_kms[0])
lineyear53.append(epoch_2.decimalyear[1])
linevlsr53.append(VLSR[1])
line_53 = np.column_stack((lineyear53, linevlsr53))

lineyear62 = []
linevlsr62 = []
lineyear62.append(df.epoch_year[2])
linevlsr62.append(df.vlsr_kms[2])
lineyear62.append(epoch_2.decimalyear[0])
linevlsr62.append(VLSR[0])
line_62 = np.column_stack((lineyear62, linevlsr62))

lineyear63 = []
linevlsr63 = []
lineyear63.append(df.epoch_year[3])
linevlsr63.append(df.vlsr_kms[3])
lineyear63.append(epoch_2.decimalyear[2])
linevlsr63.append(VLSR[2])
line_63 = np.column_stack((lineyear63, linevlsr63))

lineyear74 = []
linevlsr74 = []
lineyear74.append(df.epoch_year[5])
linevlsr74.append(df.vlsr_kms[5])
lineyear74.append(epoch_2.decimalyear[4])
linevlsr74.append(VLSR[4])
line_74 = np.column_stack((lineyear74, linevlsr74))

lineyear75 = []
linevlsr75 = []
lineyear75.append(df.epoch_year[6])
linevlsr75.append(df.vlsr_kms[6])
lineyear75.append(epoch_2.decimalyear[5])
linevlsr75.append(VLSR[5])
line_75 = np.column_stack((lineyear75, linevlsr75))

lineyear76 = []
linevlsr76 = []
lineyear76.append(epoch_2.decimalyear[9])
linevlsr76.append(VLSR[9])
lineyear76.append(epoch_2.decimalyear[10])
linevlsr76.append(VLSR[10])
lineyear76.append(df.epoch_year[8])
linevlsr76.append(df.vlsr_kms[8])
line_76 = np.column_stack((lineyear76, linevlsr76))

lineyear77 = []
linevlsr77 = []
lineyear77.append(epoch_2.decimalyear[19])
linevlsr77.append(VLSR[19])
lineyear77.append(epoch_2.decimalyear[21])
linevlsr77.append(VLSR[21])
lineyear77.append(epoch_2.decimalyear[22])
linevlsr77.append(VLSR[22])
lineyear77.append(df.epoch_year[11])
linevlsr77.append(df.vlsr_kms[11])
line_77 = np.column_stack((lineyear77, linevlsr77))

lineyear98 = []
linevlsr98 = []
lineyear98.append(df.epoch_year[14])
linevlsr98.append(df.vlsr_kms[14])
lineyear98.append(epoch_2.decimalyear[26])
linevlsr98.append(VLSR[26])
line_98 = np.column_stack((lineyear98, linevlsr98))

lineyear119 = []
linevlsr119 = []
lineyear119.append(df.epoch_year[15])
linevlsr119.append(df.vlsr_kms[15])
lineyear119.append(epoch_2.decimalyear[32])
linevlsr119.append(VLSR[32])
line_119 = np.column_stack((lineyear119, linevlsr119))

# %%
# CA3 varibility data

a = list(df.epoch_year[7:10])
b = list(df.epoch_year[10:13])
c = df.epoch_year[15]
d = list(epoch_2.decimalyear[9:11])
e = list(epoch_2.decimalyear[19:24])
f = epoch_2.decimalyear[32]
ab = a+b
epoch = list(np.append(ab,c))
epoch = epoch + d + e
epoch = list(np.append(epoch,f))
epoch

a = list(df.vlsr_kms[7:10])
b = list(df.vlsr_kms[10:13])
c = df.vlsr_kms[15]
d = VLSR[9:11]
e = VLSR[19:24]
f = VLSR[32]
ab = a+b
V = list(np.append(ab,c))
V = V + d + e
V = list(np.append(V,f))
V, epoch
# Out:
# ([51.5238986239,
#   48.9084722979,
#   47.6007591348,
#   49.9203663095,
#   47.5887284623,
#   46.4229095386,
#   47.5069724542,
#   46.02,
#   47.55,
#   45.6,
#   46.08,
#   45.66,
#   47.29,
#   49.92,
#   47.12],
#  [2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2008.8142076502731,
#   2012.2568306010928,
#   2008.808743169399,
#   2008.808743169399,
#   2008.8142076502731,
#   2012.2568306010928,
#   2012.2568306010928,
#   2012.2568306010928])

# %%
fig, ax = plt.subplots(figsize=(8,10))

ax = plt.subplot()


plt.scatter(df.epoch_year[0:2], df.vlsr_kms[0:2], color="tab:blue", marker = "^", label='(5,3)')
plt.scatter(df.epoch_year[2], df.vlsr_kms[2], color="tab:orange", marker = "s",label='(6,2)')
plt.scatter(df.epoch_year[3:5], df.vlsr_kms[3:5], color="tab:green", marker = "p", label='(6,3)')
plt.scatter(df.epoch_year[5], df.vlsr_kms[5], color="tab:red", marker = "H",label='(7,4)')
plt.scatter(df.epoch_year[6], df.vlsr_kms[6], color="tab:purple", marker = "+",label='(7,5)')
plt.scatter(df.epoch_year[7:10], df.vlsr_kms[7:10], color="tab:cyan", marker = "*", label='(7,6)')
plt.scatter(df.epoch_year[10:13], df.vlsr_kms[10:13], color="tab:pink", marker = "x", label='(7,7)')
# plt.scatter(df.epoch_year[13], df.vlsr_kms[13], color="tab:gray", marker = "D",label='(8,5)')
plt.scatter(df.epoch_year[14], df.vlsr_kms[14], color="tab:brown", marker = "v",label='(9,8)')
plt.scatter(df.epoch_year[15], df.vlsr_kms[15], color="tab:olive", marker = "8", label='(11,9)')


x = 2
y = 8
plt.errorbar(df.epoch_year[15], df.vlsr_kms[15], yerr=df.vlsr_kms_error[15], color="tab:olive",marker = "8",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[0:2], df.vlsr_kms[0:2], yerr=df.vlsr_kms_error[0:2], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[2], df.vlsr_kms[2], yerr=df.vlsr_kms_error[2],color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[3:5], df.vlsr_kms[3:5],yerr=df.vlsr_kms_error[3:5], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[5], df.vlsr_kms[5],yerr=df.vlsr_kms_error[5], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[6], df.vlsr_kms[6], yerr=df.vlsr_kms_error[6],color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[7:10], df.vlsr_kms[7:10], yerr=df.vlsr_kms_error[7:10],color="tab:cyan", marker = "*",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[10:13], df.vlsr_kms[10:13], yerr=df.vlsr_kms_error[10:13],color="tab:pink", marker = "x",ls='none',elinewidth=x,capsize=y,)
# plt.errorbar(df.epoch_year[13], df.vlsr_kms[13],yerr=df.vlsr_kms_error[13],color="tab:gray", marker = "D",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[14], df.vlsr_kms[14],yerr=df.vlsr_kms_error[14], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,)

# plt.scatter(epoch_2.decimalyear[1], VLSR[1], color="tab:blue", marker = "^")
# plt.scatter(epoch_2.decimalyear[0], VLSR[0], color="tab:orange", marker = "s")
# plt.scatter(epoch_2.decimalyear[2], VLSR[2], color="tab:green", marker = "p")
# plt.scatter(epoch_2.decimalyear[4], VLSR[4], color="tab:red", marker = "H")
# plt.scatter(epoch_2.decimalyear[5], VLSR[5], color="tab:purple", marker = "+")
# plt.scatter(epoch_2.decimalyear[9:11], VLSR[9:11], color="tab:cyan", marker = "*")
# plt.scatter(epoch_2.decimalyear[19:24], VLSR[19:24], color="tab:pink", marker = "x")
# plt.scatter(epoch_2.decimalyear[6], VLSR[6], color="tab:gray", marker = "D")
# plt.scatter(epoch_2.decimalyear[26], VLSR[26], color="tab:brown", marker = "v")
# plt.scatter(epoch_2.decimalyear[32], VLSR[32], color="tab:olive", marker = "8")

plt.errorbar(epoch_2.decimalyear[1], VLSR[1], color="tab:blue", marker = "^",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[0], VLSR[0], color="tab:orange", marker = "s",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[2], VLSR[2], color="tab:green", marker = "p",ls='none', yerr = 0.01,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[4], VLSR[4], color="tab:red", marker = "H",ls='none',yerr=0.05,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[5], VLSR[5], color="tab:purple", marker = "+",ls='none',yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[9:11], VLSR[9:11], color="tab:cyan", marker = "*",ls='none',yerr=[0.01,0.02],elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[19:24],VLSR[19:24], color="tab:pink", marker = "x",ls='none',yerr=[0.02,0.01,0.05,0.11,0.11],elinewidth=x,capsize=y,)
# plt.errorbar(epoch_2.decimalyear[6], VLSR[6], color="tab:gray", marker = "D",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[26], VLSR[26], color="tab:brown", marker = "v",ls='none', yerr=0.08,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[32], VLSR[32], color="tab:olive", marker = "8",ls='none', yerr=0.01,elinewidth=x,capsize=y,)

# plt.plot(line_85[:,0], line_85[:,1], color='tab:gray')
plt.plot(line_53[:,0], line_53[:,1], color='tab:blue')
plt.plot(line_119[:,0], line_119[:,1], color='tab:olive')
plt.plot(line_62[:,0], line_62[:,1], color='tab:orange')
plt.plot(line_63[:,0], line_63[:,1], color='tab:green')
plt.plot(line_74[:,0], line_74[:,1], color='tab:red')
plt.plot(line_75[:,0], line_75[:,1], color='tab:purple')
plt.plot(line_76[:,0], line_76[:,1], color='tab:cyan')
plt.plot(line_77[:,0], line_77[:,1], color='tab:pink')
plt.plot(line_98[:,0], line_98[:,1], color='tab:brown')

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ [km s-1]", fontsize = 18)
tick_fontsize = 16
ax.legend(title='NH3 (J,K)',fontsize = 14,title_fontsize=14,loc=2)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,45,58])
# Out:
# (2008.0, 2021.0, 45.0, 58.0)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()

plt.scatter(df.epoch_year[0:2], df.vlsr_kms[0:2], color="tab:blue", marker = "^", label='(5,3)')
plt.scatter(df.epoch_year[2], df.vlsr_kms[2], color="tab:orange", marker = "s",label='(6,2)')
plt.scatter(df.epoch_year[3:5], df.vlsr_kms[3:5], color="tab:green", marker = "p", label='(6,3)')
plt.scatter(df.epoch_year[5], df.vlsr_kms[5], color="tab:red", marker = "H",label='(7,4)')
plt.scatter(df.epoch_year[6], df.vlsr_kms[6], color="tab:purple", marker = "+",label='(7,5)')
plt.scatter(df.epoch_year[14], df.vlsr_kms[14], color="tab:brown", marker = "v",label='(9,8)')

x = 2
y = 8
plt.errorbar(df.epoch_year[0:2], df.vlsr_kms[0:2], yerr=df.vlsr_kms_error[0:2], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[2], df.vlsr_kms[2], yerr=df.vlsr_kms_error[2],color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[3:5], df.vlsr_kms[3:5],yerr=df.vlsr_kms_error[3:5], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[5], df.vlsr_kms[5],yerr=df.vlsr_kms_error[5], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[6], df.vlsr_kms[6], yerr=df.vlsr_kms_error[6],color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[14], df.vlsr_kms[14],yerr=df.vlsr_kms_error[14], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,)

plt.errorbar(epoch_2.decimalyear[1], VLSR[1], color="tab:blue", marker = "^",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[0], VLSR[0], color="tab:orange", marker = "s",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[2], VLSR[2], color="tab:green", marker = "p",ls='none', yerr = 0.01,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[4], VLSR[4], color="tab:red", marker = "H",ls='none',yerr=0.05,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[26], VLSR[26], color="tab:brown", marker = "v",ls='none', yerr=0.08,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[5], VLSR[5], color="tab:purple", marker = "+",ls='none',yerr=0.02,elinewidth=x,capsize=y,)

plt.errorbar(Zhang2022_5c3_time, Zhang2022_5c3_vlsr, color="tab:blue", marker = "^",ls='none',yerr=Zhang2022_5c3_vlsr_error,elinewidth=x,capsize=y,)
plt.errorbar(Zhang2022_6c2_time, Zhang2022_6c2_vlsr, color="tab:orange", marker = "s",ls='none',yerr=Zhang2022_6c2_vlsr_error,elinewidth=x,capsize=y,)
plt.errorbar(Zhang2022_6c3_time, Zhang2022_6c3_vlsr, color="tab:green", marker = "p",ls='none',yerr=Zhang2022_6c3_vlsr_error,elinewidth=x,capsize=y,)

plt.errorbar(Zhang2022_9c8_time, Zhang2022_9c8_vlsr, color="tab:brown", marker = "v",ls='none',yerr=Zhang2022_9c8_vlsr_error,elinewidth=x,capsize=y,)
plt.errorbar(Zhang2022_7c5_time, Zhang2022_7c5_vlsr, color="tab:purple", marker = "+",ls='none',yerr=Zhang2022_7c5_vlsr_error,elinewidth=x,capsize=y,)


plt.plot(line_53[:,0], line_53[:,1], color='tab:blue')
plt.plot(line_62[:,0], line_62[:,1], color='tab:orange')
plt.plot(line_63[:,0], line_63[:,1], color='tab:green')
plt.plot(line_74[:,0], line_74[:,1], color='tab:red')
plt.plot(line_75[:,0], line_75[:,1], color='tab:purple')
plt.plot(line_98[:,0], line_98[:,1], color='tab:brown')

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, m, b):
    # y = mx + b
    return (m*x) + b

popt, pcov = curve_fit(func, epochd2, VLSRd2)
popt

xdata = np.linspace(2011,2020.5,100)
# plt.plot(xdata, func(xdata, *popt),"black", linestyle = '--', alpha=0.3)
# error = 0.1
# ax.fill_between(xdata, func(xdata, *popt) + error,func(xdata, *popt) -error, alpha=0.05, facecolor = 'black')
# ax.text(0.05,0.05,'%0f ± blank km s$^{-1}$ yr$^{-1}$' % popt[0], fontsize = 16, transform=ax.transAxes)
ax.text(0.05,0.05,'%0a ± blank km s$^{-1}$ yr$^{-1}$' % -0.11, fontsize = 16, transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ [km s-1]", fontsize = 18)
tick_fontsize = 16
ax.legend(title='NH$_3$ (J,K)',fontsize = 14,loc=2)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,53.5,57.2])

#test
# Out:
# (2008.0, 2021.0, 53.5, 57.2)

# %% [markdown]
# ## W51d2

# %%
data_d2 = {"line": [], "epoch": [], "VLSR": [], "VLSR_error": [], "S":[],  "S_error":[]}
data_d2 = pd.DataFrame(data_d2)

# %%
lin_53_1 = pd.Series({"line": "(5,3)", "epoch": df.epoch_year[0], "VLSR": df.vlsr_kms[0], "VLSR_error": df.vlsr_kms_error[0], "S": df.S[0],  "S_error":df.S_error[0]}) #blue
lin_53_2 = pd.Series({"line": "(5,3)", "epoch": df.epoch_year[1], "VLSR": df.vlsr_kms[1], "VLSR_error": df.vlsr_kms_error[1], "S": df.S[1],  "S_error":df.S_error[1]}) 
lin_62_1 = pd.Series({"line": "(6,2)", "epoch": df.epoch_year[2], "VLSR": df.vlsr_kms[2], "VLSR_error": df.vlsr_kms_error[2], "S": df.S[2],  "S_error":df.S_error[2]}) #orange
lin_63_1 = pd.Series({"line": "(6,3)", "epoch": df.epoch_year[3], "VLSR": df.vlsr_kms[3], "VLSR_error": df.vlsr_kms_error[3], "S": df.S[3],  "S_error":df.S_error[3]}) #green
lin_63_2 = pd.Series({"line": "(6,3)", "epoch": df.epoch_year[4], "VLSR": df.vlsr_kms[4], "VLSR_error": df.vlsr_kms_error[4], "S": df.S[4],  "S_error":df.S_error[4]}) 
lin_74_1 = pd.Series({"line": "(7,4)", "epoch": df.epoch_year[5], "VLSR": df.vlsr_kms[5], "VLSR_error": df.vlsr_kms_error[5], "S": df.S[5],  "S_error":df.S_error[5]}) #red
lin_75_1 = pd.Series({"line": "(7,5)", "epoch": df.epoch_year[6], "VLSR": df.vlsr_kms[6], "VLSR_error": df.vlsr_kms_error[6], "S": df.S[6],  "S_error":df.S_error[6]}) #purple
lin_98_1 = pd.Series({"line": "(9,8)", "epoch": df.epoch_year[14], "VLSR": df.vlsr_kms[14], "VLSR_error": df.vlsr_kms_error[14], "S": df.S[14],  "S_error":df.S_error[14]}) #brown

lin_53_10 = pd.Series({"line": "(5,3)", "epoch": epoch_2.decimalyear[1], "VLSR": VLSR[1], "VLSR_error": 0.02, })
lin_62_10 = pd.Series({"line": "(6,2)", "epoch": epoch_2.decimalyear[0], "VLSR": VLSR[0], "VLSR_error": 0.02, })
lin_63_10 = pd.Series({"line": "(6,3)", "epoch": epoch_2.decimalyear[2], "VLSR": VLSR[2], "VLSR_error": 0.01,})
lin_74_10 = pd.Series({"line": "(7,4)", "epoch": epoch_2.decimalyear[4], "VLSR": VLSR[4], "VLSR_error": 0.05, })
lin_75_10 = pd.Series({"line": "(7,5)", "epoch": epoch_2.decimalyear[5], "VLSR": VLSR[5], "VLSR_error": 0.02, })
lin_98_10 = pd.Series({"line": "(9,8)", "epoch": epoch_2.decimalyear[28], "VLSR": VLSR[28], "VLSR_error": 0.08,})

lin_53_100 = pd.Series({"line": "(5,3)", "epoch": Zhang2022_5c3_time, "VLSR": Zhang2022_5c3_vlsr, "VLSR_error": Zhang2022_5c3_vlsr_error,})

# %%
lin_53_100
# Out:
# line                                                      (5,3)
# epoch         [2020.2486338797814, 2020.2650273224044, 2020....
# VLSR                             [nan, nan, 54.5, 54.45, 54.45]
# VLSR_error                          [nan, nan, 0.08, 0.02, nan]
# S                                                         2.458
# S_error                                                   0.023
# dtype: object

# %%
data_d2.loc['1'] = lin_53_1
data_d2.loc['2'] = lin_53_2
data_d2.loc['3'] = lin_62_1
data_d2.loc['4'] = lin_63_1
data_d2.loc['5'] = lin_63_2
data_d2.loc['6'] = lin_74_1
data_d2.loc['7'] = lin_75_1
data_d2.loc['8'] = lin_98_1
data_d2.loc['9'] = lin_53_10
data_d2.loc['11'] = lin_62_10
data_d2.loc['12'] = lin_63_10
data_d2.loc['14'] = lin_74_10
data_d2.loc['15'] = lin_75_10
data_d2.loc['16'] = lin_98_10

# %%
data_d2
# Out:
#      line        epoch       VLSR  VLSR_error       S  S_error
# 1   (5,3)  2019.583562  55.985888       0.004  0.4600    0.006
# 2   (5,3)  2019.583562  54.577438       0.025  0.0783    0.005
# 3   (6,2)  2019.583562  53.895252       0.033  0.0390    0.002
# 4   (6,3)  2019.583562  55.201461       0.003  0.5065    0.005
# 5   (6,3)  2019.583562  53.684104       0.014  0.1418    0.007
# 6   (7,4)  2019.583562  54.051188       0.203  0.0468    0.005
# 7   (7,5)  2019.583562  53.748378       0.014  2.4580    0.023
# 8   (9,8)  2019.583562  54.123012       0.010  0.1758    0.006
# 9   (5,3)  2012.256831  57.010000       0.020     NaN      NaN
# 11  (6,2)  2012.256831  54.390000       0.020  2.4580    0.023
# 12  (6,3)  2012.256831  56.500000       0.010  2.4580    0.023
# 14  (7,4)  2012.256831  54.740000       0.050  2.4580    0.023
# 15  (7,5)  2012.256831  54.440000       0.020  2.4580    0.023
# 16  (9,8)  1995.906849  43.790000       0.080  2.4580    0.023
# 17  (5,3)  1995.906849  43.790000       0.080  2.4580    0.023

# %% [markdown]
# ## W51CA3

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()

plt.scatter(df.epoch_year[7:10], df.vlsr_kms[7:10], color="tab:cyan", marker = "*", label='(7,6)')
plt.scatter(df.epoch_year[10:13], df.vlsr_kms[10:13], color="tab:pink", marker = "x", label='(7,7)')
plt.scatter(df.epoch_year[15], df.vlsr_kms[15], color="tab:olive", marker = "8", label='(11,9)')

x = 2
y = 8
plt.errorbar(df.epoch_year[15], df.vlsr_kms[15], yerr=df.vlsr_kms_error[15], color="tab:olive",marker = "8",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[7:10], df.vlsr_kms[7:10], yerr=df.vlsr_kms_error[7:10],color="tab:cyan", marker = "*",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[10:13], df.vlsr_kms[10:13], yerr=df.vlsr_kms_error[10:13],color="tab:pink", marker = "x",ls='none',elinewidth=x,capsize=y,)

plt.scatter(epoch_2.decimalyear[9:11], VLSR[9:11], color="tab:cyan", marker = "*")
plt.scatter(epoch_2.decimalyear[19:24], VLSR[19:24], color="tab:pink", marker = "x")
plt.scatter(epoch_2.decimalyear[32], VLSR[32], color="tab:olive", marker = "8")

plt.errorbar(epoch_2.decimalyear[9:11], VLSR[9:11], color="tab:cyan", marker = "*",ls='none',yerr=[0.01,0.02],elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[19:24],VLSR[19:24], color="tab:pink", marker = "x",ls='none',yerr=[0.02,0.01,0.05,0.11,0.11],elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[32], VLSR[32], color="tab:olive", marker = "8",ls='none', yerr=0.01,elinewidth=x,capsize=y,)

plt.errorbar(Zhang2022_7c6_time, Zhang2022_7c6_vlsr, color="tab:cyan", marker = "*",ls='none',yerr=Zhang2022_7c6_vlsr_error,elinewidth=x,capsize=y,)
plt.errorbar(Zhang2022_11c9_time, Zhang2022_11c9_vlsr, color="tab:olive", marker = "*",ls='none',yerr=Zhang2022_11c9_vlsr_error,elinewidth=x,capsize=y,)

plt.plot(line_119[:,0], line_119[:,1], color='tab:olive')
plt.plot(line_76[:,0], line_76[:,1], color='tab:cyan')
plt.plot(line_77[:,0], line_77[:,1], color='tab:pink')

varibility = np.concatenate(([df.epoch_year[7:10],df.epoch_year[10:13],df.epoch_year[15],
                               epoch_2.decimalyear[9:11],epoch_2.decimalyear[19:24],epoch_2.decimalyear[32]],
                              [df.vlsr_kms[7:10],df.vlsr_kms[10:13],df.vlsr_kms[15],
                              VLSR[9:11],VLSR[19:24],VLSR[32]]))

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, m, b):
    # y = mx + b
    return (m*x) + b

popt, pcov = curve_fit(func, epoch, V)
popt

xdata = np.linspace(2008,2020.5,50)
# plt.plot(xdata, func(xdata, *popt),"black", linestyle = '--', alpha=0.3)
# error = 0.1
# ax.fill_between(xdata, func(xdata, *popt) + error,func(xdata, *popt) -error, alpha=0.05, facecolor = 'black')
ax.text(0.4,0.05,'+%0a ± blank km s$^{-1}$ yr$^{-1}$' % 0.24, fontsize = 16, transform=ax.transAxes)

print('fit: m=%0f, b=%0f' % tuple(popt))
_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,45,52])
# Out:
# fit: m=0.207693, b=-370.804257
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# (2008.0, 2021.0, 45.0, 52.0)

# %%
epoch_2.decimalyear[19:24]
Zhang2022_7c6_time

# %%
df
# Out:
#        line         dec         ra     dec_error      ra_error   vlsr_kms  \
# 0    (5, 3)  290.915896  14.518001  7.740000e-07  7.740000e-07  55.985888
# 1    (5, 3)  290.915926  14.518009  1.650000e-06  1.650000e-06  54.577438
# 2    (6, 2)  290.915900  14.518010  2.230000e-06  2.350000e-06  53.895252
# 3    (6, 3)  290.915894  14.518001  7.100000e-07  7.090000e-07  55.201461
# 4    (6, 3)  290.915926  14.518010  9.250000e-07  1.000000e-06  53.684104
# 5    (7, 4)  290.915899  14.518008  1.510000e-06  1.510000e-06  54.051188
# 6    (7, 5)  290.915898  14.518011  7.280000e-07  7.250000e-07  53.748378
# 7    (7, 6)  290.917076  14.518232  9.590000e-07  9.530000e-07  51.523899
# 8    (7, 6)  290.917077  14.518232  1.150000e-06  1.150000e-06  48.908472
# 9    (7, 6)  290.917077  14.518231  9.350000e-07  9.270000e-07  47.600759
# 10   (7, 7)  290.917080  14.518232  2.500000e-06  2.500000e-06  49.920366
# 11   (7, 7)  290.917076  14.518232  4.800000e-07  4.800000e-07  47.588728
# 12   (7, 7)  290.917076  14.518232  7.260000e-07  7.260000e-07  46.422910
# 13   (8, 5)  290.915899  14.518009  1.030000e-06  1.030000e-06  54.304837
# 14   (9, 8)  290.915898  14.518009  1.250000e-06  1.250000e-06  54.123012
# 15  (11, 9)  290.917076  14.518231  7.160000e-07  7.150000e-07  47.506972
# 16  (11, 9)  290.916824  14.518223  1.820000e-06  1.340000e-06  61.734877
# 17  (11, 9)  290.916989  14.518159  3.270000e-06  3.270000e-06  60.312086
#
#     vlsr_kms_error       S                    epoch   epoch_year
# 0            0.004  0.4600  2019-08-02T00:00:00.000  2019.583562
# 1            0.025  0.0783  2019-08-02T00:00:00.000  2019.583562
# 2            0.033  0.0390  2019-08-02T00:00:00.000  2019.583562
# 3            0.003  0.5065  2019-08-02T00:00:00.000  2019.583562
# 4            0.014  0.1418  2019-08-02T00:00:00.000  2019.583562
# 5            0.203  0.0468  2019-08-02T00:00:00.000  2019.583562
# 6            0.014  2.4580  2019-08-02T00:00:00.000  2019.583562
# 7            0.012  0.2357  2019-08-02T00:00:00.000  2019.583562
# 8            0.013  0.2512  2019-08-02T00:00:00.000  2019.583562
# 9            0.008  0.3645  2019-08-02T00:00:00.000  2019.583562
# 10           0.115  0.0433  2019-08-02T00:00:00.000  2019.583562
# 11           0.007  0.5501  2019-08-02T00:00:00.000  2019.583562
# 12           0.022  0.2278  2019-08-02T00:00:00.000  2019.583562
# 13           0.012  0.1123  2019-08-02T00:00:00.000  2019.583562
# 14           0.010  0.1758  2019-08-02T00:00:00.000  2019.583562
# 15           0.007  0.4160  2019-08-02T00:00:00.000  2019.583562
# 16             NaN  0.0834  2019-08-02T00:00:00.000  2019.583562
# 17             NaN  0.0376  2019-08-02T00:00:00.000  2019.583562

# %%
S_error = [0.006,0.005,0.002,0.005,0.007,0.005,0.023,0.006,0.005,0.006,0.006,0.004,0.006,0.004,0.006,0.006,0.005,0.004]
df['S_error'] = S_error

# %%
df
# Out:
#        line         dec         ra     dec_error      ra_error   vlsr_kms  \
# 0    (5, 3)  290.915896  14.518001  7.740000e-07  7.740000e-07  55.985888
# 1    (5, 3)  290.915926  14.518009  1.650000e-06  1.650000e-06  54.577438
# 2    (6, 2)  290.915900  14.518010  2.230000e-06  2.350000e-06  53.895252
# 3    (6, 3)  290.915894  14.518001  7.100000e-07  7.090000e-07  55.201461
# 4    (6, 3)  290.915926  14.518010  9.250000e-07  1.000000e-06  53.684104
# 5    (7, 4)  290.915899  14.518008  1.510000e-06  1.510000e-06  54.051188
# 6    (7, 5)  290.915898  14.518011  7.280000e-07  7.250000e-07  53.748378
# 7    (7, 6)  290.917076  14.518232  9.590000e-07  9.530000e-07  51.523899
# 8    (7, 6)  290.917077  14.518232  1.150000e-06  1.150000e-06  48.908472
# 9    (7, 6)  290.917077  14.518231  9.350000e-07  9.270000e-07  47.600759
# 10   (7, 7)  290.917080  14.518232  2.500000e-06  2.500000e-06  49.920366
# 11   (7, 7)  290.917076  14.518232  4.800000e-07  4.800000e-07  47.588728
# 12   (7, 7)  290.917076  14.518232  7.260000e-07  7.260000e-07  46.422910
# 13   (8, 5)  290.915899  14.518009  1.030000e-06  1.030000e-06  54.304837
# 14   (9, 8)  290.915898  14.518009  1.250000e-06  1.250000e-06  54.123012
# 15  (11, 9)  290.917076  14.518231  7.160000e-07  7.150000e-07  47.506972
# 16  (11, 9)  290.916824  14.518223  1.820000e-06  1.340000e-06  61.734877
# 17  (11, 9)  290.916989  14.518159  3.270000e-06  3.270000e-06  60.312086
#
#     vlsr_kms_error       S                    epoch   epoch_year  S_error
# 0            0.004  0.4600  2019-08-02T00:00:00.000  2019.583562    0.006
# 1            0.025  0.0783  2019-08-02T00:00:00.000  2019.583562    0.005
# 2            0.033  0.0390  2019-08-02T00:00:00.000  2019.583562    0.002
# 3            0.003  0.5065  2019-08-02T00:00:00.000  2019.583562    0.005
# 4            0.014  0.1418  2019-08-02T00:00:00.000  2019.583562    0.007
# 5            0.203  0.0468  2019-08-02T00:00:00.000  2019.583562    0.005
# 6            0.014  2.4580  2019-08-02T00:00:00.000  2019.583562    0.023
# 7            0.012  0.2357  2019-08-02T00:00:00.000  2019.583562    0.006
# 8            0.013  0.2512  2019-08-02T00:00:00.000  2019.583562    0.005
# 9            0.008  0.3645  2019-08-02T00:00:00.000  2019.583562    0.006
# 10           0.115  0.0433  2019-08-02T00:00:00.000  2019.583562    0.006
# 11           0.007  0.5501  2019-08-02T00:00:00.000  2019.583562    0.004
# 12           0.022  0.2278  2019-08-02T00:00:00.000  2019.583562    0.006
# 13           0.012  0.1123  2019-08-02T00:00:00.000  2019.583562    0.004
# 14           0.010  0.1758  2019-08-02T00:00:00.000  2019.583562    0.006
# 15           0.007  0.4160  2019-08-02T00:00:00.000  2019.583562    0.006
# 16             NaN  0.0834  2019-08-02T00:00:00.000  2019.583562    0.005
# 17             NaN  0.0376  2019-08-02T00:00:00.000  2019.583562    0.004

# %%
import numpy as np
lineyear = []
linevlsr = []
lineyear.append(df.epoch_year[13])
linevlsr.append(df.vlsr_kms[13])
lineyear.append(epoch_2.decimalyear[6])
linevlsr.append(VLSR[6])
line_85 = np.column_stack((lineyear, linevlsr))

lineyear53 = []
linevlsr53 = []
lineyear53.append(df.epoch_year[0])
linevlsr53.append(df.vlsr_kms[0])
lineyear53.append(epoch_2.decimalyear[1])
linevlsr53.append(VLSR[1])
line_53 = np.column_stack((lineyear53, linevlsr53))

lineyear62 = []
linevlsr62 = []
lineyear62.append(df.epoch_year[2])
linevlsr62.append(df.vlsr_kms[2])
lineyear62.append(epoch_2.decimalyear[0])
linevlsr62.append(VLSR[0])
line_62 = np.column_stack((lineyear62, linevlsr62))

lineyear63 = []
linevlsr63 = []
lineyear63.append(df.epoch_year[3])
linevlsr63.append(df.vlsr_kms[3])
lineyear63.append(epoch_2.decimalyear[2])
linevlsr63.append(VLSR[2])
line_63 = np.column_stack((lineyear63, linevlsr63))

lineyear74 = []
linevlsr74 = []
lineyear74.append(df.epoch_year[5])
linevlsr74.append(df.vlsr_kms[5])
lineyear74.append(epoch_2.decimalyear[4])
linevlsr74.append(VLSR[4])
line_74 = np.column_stack((lineyear74, linevlsr74))

lineyear75 = []
linevlsr75 = []
lineyear75.append(df.epoch_year[6])
linevlsr75.append(df.vlsr_kms[6])
lineyear75.append(epoch_2.decimalyear[5])
linevlsr75.append(VLSR[5])
line_75 = np.column_stack((lineyear75, linevlsr75))

lineyear76 = []
linevlsr76 = []
lineyear76.append(epoch_2.decimalyear[9])
linevlsr76.append(VLSR[9])
lineyear76.append(epoch_2.decimalyear[10])
linevlsr76.append(VLSR[10])
lineyear76.append(df.epoch_year[8])
linevlsr76.append(df.vlsr_kms[8])
line_76 = np.column_stack((lineyear76, linevlsr76))

lineyear77 = []
linevlsr77 = []
lineyear77.append(epoch_2.decimalyear[19])
linevlsr77.append(VLSR[19])
lineyear77.append(epoch_2.decimalyear[21])
linevlsr77.append(VLSR[21])
lineyear77.append(epoch_2.decimalyear[22])
linevlsr77.append(VLSR[22])
lineyear77.append(df.epoch_year[11])
linevlsr77.append(df.vlsr_kms[11])
line_77 = np.column_stack((lineyear77, linevlsr77))

lineyear98 = []
linevlsr98 = []
lineyear98.append(df.epoch_year[14])
linevlsr98.append(df.vlsr_kms[14])
lineyear98.append(epoch_2.decimalyear[26])
linevlsr98.append(VLSR[26])
line_98 = np.column_stack((lineyear98, linevlsr98))

lineyear119 = []
linevlsr119 = []
lineyear119.append(df.epoch_year[15])
linevlsr119.append(df.vlsr_kms[15])
lineyear119.append(epoch_2.decimalyear[32])
linevlsr119.append(VLSR[32])
line_119 = np.column_stack((lineyear119, linevlsr119))

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()

plt.scatter(df.epoch_year[0:2], df.S[0:2], color="tab:blue", marker = "^", label='(5,3)')
plt.scatter(df.epoch_year[2], df.S[2], color="tab:orange", marker = "s",label='(6,2)')
plt.scatter(df.epoch_year[3:5], df.S[3:5], color="tab:green", marker = "p", label='(6,3)')
plt.scatter(df.epoch_year[5], df.S[5], color="tab:red", marker = "H",label='(7,4)')
plt.scatter(df.epoch_year[6], df.S[6], color="tab:purple", marker = "+",label='(7,5)')
plt.scatter(df.epoch_year[14], df.S[14], color="tab:brown", marker = "v",label='(9,8)')

x = 2
y = 8
plt.errorbar(df.epoch_year[0:2], df.S[0:2], yerr=df.S_error[0:2], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[2], df.S[2], yerr=df.S_error[2],color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[3:5], df.S[3:5],yerr=df.S_error[3:5], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[5], df.S[5],yerr=df.S_error[5], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[6], df.S[6], yerr=df.S_error[6],color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[14], df.S[14],yerr=df.S_error[14], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,)

plt.errorbar(epoch_2.decimalyear[1], S[1], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[0], S[0], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[2], S[2], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[4], S[4], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[5], S[5], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[26], S[26], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,)

plt.plot(line_53[:,0], line_53[:,1], color='tab:blue')
plt.plot(line_62[:,0], line_62[:,1], color='tab:orange')
plt.plot(line_63[:,0], line_63[:,1], color='tab:green')
plt.plot(line_74[:,0], line_74[:,1], color='tab:red')
plt.plot(line_75[:,0], line_75[:,1], color='tab:purple')
plt.plot(line_98[:,0], line_98[:,1], color='tab:brown')

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, m, b):
    # y = mx + b
    return (m*x) + b

popt, pcov = curve_fit(func, epochd2, VLSRd2)
popt

xdata = np.linspace(2011,2020.5,100)
# plt.plot(xdata, func(xdata, *popt),"black", linestyle = '--', alpha=0.3)
# error = 0.1
# ax.fill_between(xdata, func(xdata, *popt) + error,func(xdata, *popt) -error, alpha=0.05, facecolor = 'black')
# ax.text(0.05,0.05,'%0f ± blank km s$^{-1}$ yr$^{-1}$' % popt[0], fontsize = 16, transform=ax.transAxes)
ax.text(0.05,0.05,'%0a ± blank km s$^{-1}$ yr$^{-1}$' % -0.11, fontsize = 16, transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ [km s-1]", fontsize = 18)
tick_fontsize = 16
ax.legend(title='NH$_3$ (J,K)',fontsize = 14,loc=2)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,-.08,0.6])

#test
# Out:
# (2008.0, 2021.0, -0.08, 0.6)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()

plt.scatter(df.epoch_year[7:10], df.S[7:10], color="tab:cyan", marker = "*", label='(7,6)')
plt.scatter(df.epoch_year[10:13], df.S[10:13], color="tab:pink", marker = "x", label='(7,7)')
plt.scatter(df.epoch_year[15], df.S[15], color="tab:olive", marker = "8", label='(11,9)')

x = 2
y = 8
plt.errorbar(df.epoch_year[15], df.S[15], yerr=df.S_error[15], color="tab:olive",marker = "8",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[7:10], df.S[7:10], yerr=df.S_error[7:10],color="tab:cyan", marker = "*",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[10:13], df.S[10:13], yerr=df.S_error[10:13],color="tab:pink", marker = "x",ls='none',elinewidth=x,capsize=y,)

# plt.scatter(epoch_2.decimalyear[9:11], S[9:11], color="tab:cyan", marker = "*")
# plt.scatter(epoch_2.decimalyear[19:24], S[19:24], color="tab:pink", marker = "x")
# plt.scatter(epoch_2.decimalyear[32], S[32], color="tab:olive", marker = "8")

plt.errorbar(epoch_2.decimalyear[9:11], S[9:11], color="tab:cyan", marker = "*",ls='none',yerr=[0.01,0.02],elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[19:24],S[19:24], color="tab:pink", marker = "x",ls='none',yerr=[0.02,0.01,0.05,0.11,0.11],elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[32], S[32], color="tab:olive", marker = "8",ls='none', yerr=0.01,elinewidth=x,capsize=y,)

# plt.plot(line_119[:,0], line_119[:,1], color='tab:olive')
# plt.plot(line_76[:,0], line_76[:,1], color='tab:cyan')
# plt.plot(line_77[:,0], line_77[:,1], color='tab:pink')

plt.errorbar(Zhang2022_7c6_time, Zhang2022_7c6_S, color="tab:cyan", marker = "*",ls='none',yerr=Zhang2022_7c6_S_error,elinewidth=x,capsize=y,)
plt.errorbar(Zhang2022_11c9_time, Zhang2022_11c9_S, color="tab:olive", marker = "*",ls='none',yerr=Zhang2022_11c9_S_error,elinewidth=x,capsize=y,)

# varibility = np.concatenate(([df.epoch_year[7:10],df.epoch_year[10:13],df.epoch_year[15],
#                                epoch_2.decimalyear[9:11],epoch_2.decimalyear[19:24],epoch_2.decimalyear[32]],
#                               [df.vlsr_kms[7:10],df.vlsr_kms[10:13],df.vlsr_kms[15],
#                               VLSR[9:11],VLSR[19:24],VLSR[32]]))

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, m, b):
    # y = mx + b
    return (m*x) + b

popt, pcov = curve_fit(func, epoch, V)
popt

xdata = np.linspace(2008,2020.5,50)
# plt.plot(xdata, func(xdata, *popt),"black", linestyle = '--', alpha=0.3)
# error = 0.1
# ax.fill_between(xdata, func(xdata, *popt) + error,func(xdata, *popt) -error, alpha=0.05, facecolor = 'black')
ax.text(0.4,0.05,'+%0a ± blank km s$^{-1}$ yr$^{-1}$' % 0.24, fontsize = 16, transform=ax.transAxes)

print('fit: m=%0f, b=%0f' % tuple(popt))
_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ [km s-1]", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=1,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,-0.45,3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/local/57040925/ipykernel_130013/1772241872.py in <module>
#      17 # plt.scatter(epoch_2.decimalyear[32], S[32], color="tab:olive", marker = "8")
#      18
# ---> 19 plt.errorbar(epoch_2.decimalyear[9:11], S[9:11], color="tab:cyan", marker = "*",ls='none',yerr=[0.01,0.02],elinewidth=x,capsize=y,)
#      20 plt.errorbar(epoch_2.decimalyear[19:24],S[19:24], color="tab:pink", marker = "x",ls='none',yerr=[0.02,0.01,0.05,0.11,0.11],elinewidth=x,capsize=y,)
#      21 plt.errorbar(epoch_2.decimalyear[32], S[32], color="tab:olive", marker = "8",ls='none', yerr=0.01,elinewidth=x,capsize=y,)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2770         uplims=False, xlolims=False, xuplims=False, errorevery=1,
#    2771         capthick=None, *, data=None, **kwargs):
# -> 2772     return gca().errorbar(
#    2773         x, y, yerr=yerr, xerr=xerr, fmt=fmt, ecolor=ecolor,
#    2774         elinewidth=elinewidth, capsize=capsize, barsabove=barsabove,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3295
#    3296         if len(x) != len(y):
# -> 3297             raise ValueError("'x' and 'y' must have the same size")
#    3298
#    3299         if xerr is not None:
#
# ValueError: 'x' and 'y' must have the same size

# %%
print(S)
# Out:
# [0.22, 0.3, 0.35, 0.52, 0.09, 3.1, 0.14, 6.2, 5.3, 1.95, 2.0, 1.29, 0.8, 6.8, 3.75, 1.15, 7.8, 4.9, 1.1, 1.7, 2.48, 2.27, 0.2, 0.18, 0.08, 0.03, 0.22, 0.16, 0.15, 0.12, 0.07, 0.34, 1.24, 0.14, 0.12, 0.1, 0.6, nan]

# %%
df_Zhang2022 = pd.read_csv('/orange/adamginsburg/w51/vla/19A-254/derod/W51-Masers-and-Starforming-Regions/notebooks/apjsac60a0t2_mrt.csv')
df_Zhang2022
# Out:
#     Transition         Date  Q_V_c  Q_V_c_error Unnamed: 4   T_p  T_p_error  \
# 0        (7,3)   2020-01-08  60.72         0.90        NaN  0.10       0.03
# 1        (7,3)   2020-03-16  63.51         0.56        NaN  0.13       0.03
# 2        (7,3)   2020-04-01  59.68         0.69        NaN  0.13       0.07
# 3        (7,3)   2020-04-07  61.00         1.42        NaN  0.03       0.07
# 4       (10,7)   2020-04-01    NaN          NaN        NaN   NaN        NaN
# ..         ...          ...    ...          ...        ...   ...        ...
# 194      (6,6)   2020-04-01  59.89         0.13        NaN  0.87       0.07
# 195      (7,7)   2020-03-14  60.65         0.93        NaN  0.15       0.07
# 196      (7,7)   2020-03-16  60.26         1.21        NaN  0.33       0.13
# 197      (7,7)  * 2020-3-20  57.12         0.40        NaN  0.24       0.07
# 198      (7,7)   2020-04-01  60.04         0.23        NaN  0.37       0.01
#
#     delta_V  delta_V_error Unnamed: 9     W        W_error  M_V_c  \
# 0      11.9           2.04        NaN  1.17           0.17  54.03
# 1     11.34           1.17        NaN  1.53           0.13  53.79
# 2      8.58           1.58        NaN  1.27            0.2  53.89
# 3      7.98           3.00        NaN  0.40           0.13  53.80
# 4       NaN            NaN        NaN   NaN            NaN  54.08
# ..      ...            ...        ...   ...            ...    ...
# 194   11.02           0.34        NaN  7.36  0.20 16.2 0.7    NaN
# 195       9           1.82        NaN  3.16  0.20 11.9 3.3    NaN
# 196    7.24           2.52        NaN  1.67            0.5    NaN
# 197   10.34           1.00        NaN  3.16           0.27    NaN
# 198   11.08           0.53        NaN  4.23  0.23 17.2 0.4    NaN
#
#      M_V_c_error Unnamed: 14   S_p  S_p_error  V_r_low  V_r_upp
# 0           0.13         NaN  0.08       0.03     53.5     54.5
# 1           0.03         NaN  0.23       0.02     53.2     54.4
# 2           0.03         NaN  0.41       0.04     53.3     54.5
# 3           0.02         NaN  0.14       0.03     50.4     54.2
# 4           0.00         NaN  3.69       0.10     53.7     54.5
# ..           ...         ...   ...        ...      ...      ...
# 194          NaN         NaN   NaN        NaN      NaN      NaN
# 195          NaN         NaN   NaN        NaN      NaN      NaN
# 196          NaN         NaN   NaN        NaN      NaN      NaN
# 197          NaN         NaN   NaN        NaN      NaN      NaN
# 198          NaN         NaN   NaN        NaN      NaN      NaN
#
# [199 rows x 19 columns]

# %%
df_Zhang2022[142:149]
t_4 = df_Zhang2022['Date'][142:149].astype(str)
vlsr = df_Zhang2022['M_V_c'][142:149].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][142:149].astype(float)
S = df_Zhang2022['S_p'][142:149].astype(float)
S_error = df_Zhang2022['S_p_error'][142:149].astype(float)

Zhang2022_7c6_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c6_time.append(t.decimalyear)

Zhang2022_7c6_vlsr = []
for i in vlsr:
    Zhang2022_7c6_vlsr.append(i)

Zhang2022_7c6_vlsr_error = []
for i in vlsrerror:
    Zhang2022_7c6_vlsr_error.append(i)

Zhang2022_7c6_S = []
for i in S:
    Zhang2022_11c9_S.append(i)

Zhang2022_7c6_S_error = []
for i in S_error:
    Zhang2022_7c6_S_error.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/57040925/ipykernel_130013/685934790.py in <module>
#      21 Zhang2022_7c6_S = []
#      22 for i in S:
# ---> 23     Zhang2022_11c9_S.append(i)
#      24
#      25 Zhang2022_7c6_S_error = []
#
# NameError: name 'Zhang2022_11c9_S' is not defined

# %%
df_Zhang2022[107:109]
t_4 = df_Zhang2022['Date'][107:109].astype(str)
vlsr = df_Zhang2022['M_V_c'][107:109].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][107:109].astype(float)
S = df_Zhang2022['S_p'][107:109].astype(float)
S_error = df_Zhang2022['S_p_error'][107:109].astype(float)

Zhang2022_11c9_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_11c9_time.append(t.decimalyear)

Zhang2022_11c9_vlsr = []
for i in vlsr:
    Zhang2022_11c9_vlsr.append(i)

Zhang2022_11c9_vlsr_error = []
for i in vlsrerror:
    Zhang2022_11c9_vlsr_error.append(i)

Zhang2022_11c9_S = []
for i in S:
    Zhang2022_11c9_S.append(i)

Zhang2022_11c9_S_error = []
for i in S_error:
    Zhang2022_11c9_S_error.append(i)

# %%
# df_Zhang2022[142:149]
# t_4 = df_Zhang2022['Date'][142:149].astype(str)
# vlsr = df_Zhang2022['M_V_c'][142:149].astype(float)
# vlsrerror = df_Zhang2022['M_V_c_error'][142:149].astype(float)
# S = df_Zhang2022['S_p'][142:149].astype(float)
# S_error = df_Zhang2022['S_p_error'][142:149].astype(float)

# Zhang2022_7c6_time = []
# for i in t_4:
#     t = Time(i)
#     Zhang2022_7c6_time.append(t.decimalyear)

# Zhang2022_7c6_vlsr = []
# for i in vlsr:
#     Zhang2022_7c6_vlsr.append(i)

# Zhang2022_7c6_vlsr_error = []
# for i in vlsrerror:
#     Zhang2022_7c6_vlsr_error.append(i)

# Zhang2022_7c6_S = []
# for i in S:
#     Zhang2022_11c9_S.append(i)

# Zhang2022_7c6_S_error = []
# for i in S_error:
#     Zhang2022_7c6_S_error.append(i)

# %%
df_Zhang2022[50:54]
t_4 = df_Zhang2022['Date'][50:54].astype(str)
vlsr = df_Zhang2022['M_V_c'][50:54].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][50:54].astype(float)

Zhang2022_6c2_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_6c2_time.append(t.decimalyear)

Zhang2022_6c2_vlsr = []
for i in vlsr:
    Zhang2022_6c2_vlsr.append(i)

Zhang2022_6c2_vlsr_error = []
for i in vlsrerror:
    Zhang2022_6c2_vlsr_error.append(i)

# %%
df_Zhang2022[58:65]
t_4 = df_Zhang2022['Date'][58:65].astype(str)
vlsr = df_Zhang2022['M_V_c'][58:65].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][58:65].astype(float)

Zhang2022_6c3_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_6c3_time.append(t.decimalyear)

Zhang2022_6c3_vlsr = []
for i in vlsr:
    Zhang2022_6c3_vlsr.append(i)

Zhang2022_6c3_vlsr_error = []
for i in vlsrerror:
    Zhang2022_6c3_vlsr_error.append(i)

# %%
df_Zhang2022[157:162]
t_4 = df_Zhang2022['Date'][157:162].astype(str)
vlsr = df_Zhang2022['M_V_c'][157:162].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][157:162].astype(float)

Zhang2022_5c3_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_5c3_time.append(t.decimalyear)

Zhang2022_5c3_vlsr = []
for i in vlsr:
    Zhang2022_5c3_vlsr.append(i)

Zhang2022_5c3_vlsr_error = []
for i in vlsrerror:
    Zhang2022_5c3_vlsr_error.append(i)

# %%
df_Zhang2022[137:144]
t_4 = df_Zhang2022['Date'][137:144].astype(str)
vlsr = df_Zhang2022['M_V_c'][137:144].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][137:144].astype(float)

Zhang2022_7c5_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c5_time.append(t.decimalyear)

Zhang2022_7c5_vlsr = []
for i in vlsr:
    Zhang2022_7c5_vlsr.append(i)

Zhang2022_7c5_vlsr_error = []
for i in vlsrerror:
    Zhang2022_7c5_vlsr_error.append(i)

# %%
df_Zhang2022[159:164]
t_4 = df_Zhang2022['Date'][159:164].astype(str)
vlsr = df_Zhang2022['M_V_c'][159:164].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][159:164].astype(float)

Zhang2022_9c8_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_9c8_time.append(t.decimalyear)

Zhang2022_9c8_vlsr = []
for i in vlsr:
    Zhang2022_9c8_vlsr.append(i)

Zhang2022_9c8_vlsr_error = []
for i in vlsrerror:
    Zhang2022_9c8_vlsr_error.append(i)

# %%
# df_Zhang2022[93:100]
# t_4 = df_Zhang2022['Date'][93:100].astype(str)
# vlsr = df_Zhang2022['M_V_c'][93:100].astype(float)
# vlsrerror = df_Zhang2022['M_V_c_error'][93:100].astype(float)

# Zhang2022_7c5_time = []
# for i in t_4:
#     t = Time(i)
#     Zhang2022_7c5_time.append(t.decimalyear)

# Zhang2022_7c5_vlsr = []
# for i in vlsr:
#     Zhang2022_7c5_vlsr.append(i)

# Zhang2022_7c5_vlsr_error = []
# for i in vlsrerror:
#     Zhang2022_7c5_vlsr_error.append(i)

# %%
Zhang2022_7c6_vlsr_error
# Out:
# [0.02, 0.25, 0.03, 0.08, 0.07, 0.12, nan]

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()

plt.scatter(df.epoch_year[0:2], df.vlsr_kms[0:2], color="tab:blue", marker = "^", label='(5,3)')
plt.scatter(df.epoch_year[2], df.vlsr_kms[2], color="tab:orange", marker = "s",label='(6,2)')
plt.scatter(df.epoch_year[3:5], df.vlsr_kms[3:5], color="tab:green", marker = "p", label='(6,3)')
plt.scatter(df.epoch_year[5], df.vlsr_kms[5], color="tab:red", marker = "H",label='(7,4)')
plt.scatter(df.epoch_year[6], df.vlsr_kms[6], color="tab:purple", marker = "+",label='(7,5)')
plt.scatter(df.epoch_year[14], df.vlsr_kms[14], color="tab:brown", marker = "v",label='(9,8)')

x = 2
y = 8
plt.errorbar(df.epoch_year[0:2], df.vlsr_kms[0:2], yerr=df.vlsr_kms_error[0:2], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[2], df.vlsr_kms[2], yerr=df.vlsr_kms_error[2],color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[3:5], df.vlsr_kms[3:5],yerr=df.vlsr_kms_error[3:5], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[5], df.vlsr_kms[5],yerr=df.vlsr_kms_error[5], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[6], df.vlsr_kms[6], yerr=df.vlsr_kms_error[6],color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,)
plt.errorbar(df.epoch_year[14], df.vlsr_kms[14],yerr=df.vlsr_kms_error[14], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,)

plt.errorbar(epoch_2.decimalyear[1], VLSR[1], color="tab:blue", marker = "^",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[0], VLSR[0], color="tab:orange", marker = "s",ls='none', yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[2], VLSR[2], color="tab:green", marker = "p",ls='none', yerr = 0.01,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[4], VLSR[4], color="tab:red", marker = "H",ls='none',yerr=0.05,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[5], VLSR[5], color="tab:purple", marker = "+",ls='none',yerr=0.02,elinewidth=x,capsize=y,)
plt.errorbar(epoch_2.decimalyear[26], VLSR[26], color="tab:brown", marker = "v",ls='none', yerr=0.08,elinewidth=x,capsize=y,)

plt.plot(line_53[:,0], line_53[:,1], color='tab:blue')
plt.plot(line_62[:,0], line_62[:,1], color='tab:orange')
plt.plot(line_63[:,0], line_63[:,1], color='tab:green')
plt.plot(line_74[:,0], line_74[:,1], color='tab:red')
plt.plot(line_75[:,0], line_75[:,1], color='tab:purple')
plt.plot(line_98[:,0], line_98[:,1], color='tab:brown')

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, m, b):
    # y = mx + b
    return (m*x) + b

popt, pcov = curve_fit(func, epochd2, VLSRd2)
popt

xdata = np.linspace(2011,2020.5,100)
# plt.plot(xdata, func(xdata, *popt),"black", linestyle = '--', alpha=0.3)
# error = 0.1
# ax.fill_between(xdata, func(xdata, *popt) + error,func(xdata, *popt) -error, alpha=0.05, facecolor = 'black')
# ax.text(0.05,0.05,'%0f ± blank km s$^{-1}$ yr$^{-1}$' % popt[0], fontsize = 16, transform=ax.transAxes)
ax.text(0.05,0.05,'%0a ± blank km s$^{-1}$ yr$^{-1}$' % -0.11, fontsize = 16, transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$\\nu_{LSR}$ [km s-1]", fontsize = 18)
tick_fontsize = 16
ax.legend(title='NH$_3$ (J,K)',fontsize = 14,loc=2)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,53.5,57.2])

#test
# Out:
# (2008.0, 2021.0, 53.5, 57.2)
