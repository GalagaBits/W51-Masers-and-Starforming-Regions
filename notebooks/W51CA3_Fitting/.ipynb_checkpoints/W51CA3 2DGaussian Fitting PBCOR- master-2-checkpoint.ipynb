# %% [markdown]
# # W51CA3 2DGaussian Fitting PBCOR

# %% [markdown]
# #### ALMA Band 6 (1 mm = 226 GHz) continuum
# `/orange/adamginsburg/w51/FITS/W51n_cont_briggsSC_tclean.image.fits`

# %%
directory1 = '/orange/adamginsburg/w51/FITS/W51n_cont_briggsSC_tclean.image.fits'

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u

#Accessing Cube Data
cube = SpectralCube.read(directory1, format='fits')
cube = cube[0,:,:]
x, y = 3295, 3580
size = 13

cube_cutout = cube[y - size:y + size, x - size:x + size]
yy, xx = cube_cutout.spatial_coordinate_map

cord = cube.world[y,x]

p_init_gauss2D = models.Gaussian2D(x_mean=cord[1], y_mean=cord[0], amplitude=0.03 * (u.Jy/u.beam),
                                   x_stddev=1.111111e-5 * u.degree, y_stddev=1.111111e-5 * u.degree, theta=1.5*u.rad)

fit_p = fitting.LevMarLSQFitter()


cube_cutout_quant = cube_cutout



with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, cube_cutout_quant)


p_init_gauss2D.theta.fixed = True

cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

              
plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 ALMA Band 6 (1 mm) continuum", fontsize=18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(cube_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(cube_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

#saveplotfig_gaussianfit()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# Parameter Error
#
# 7.949175317e-03 2.537724792e-04
#
# 2.90917076e+02 1.224428804e-07
#
# 1.45182376e+01 1.211903920e-07
#
# 3.577235901e-06 1.176348935e-07
#
# 4.368343544e-06 1.261432863e-07
#
# 9.1616016e-01 3.332209776e-01

# %% [markdown]
# #### ALMA Band 3 (3mm) continuum
#
# `/orange/adamginsburg/w51/2017.1.00293.S/may2021_successful_imaging/w51n.spw0thru19.14500.robust0.thr0.075mJy.mfs.I.startmod.selfcal7.image.tt0.pbcor`

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u

from astropy.visualization import quantity_support
import pylab as pl

#Saving methods
directory1 = '/orange/adamginsburg/w51/2017.1.00293.S/may2021_successful_imaging/w51n.spw0thru19.14500.robust0.thr0.075mJy.mfs.I.startmod.selfcal7.image.tt0.pbcor'

#Accessing Cube Data
cube = SpectralCube.read(directory1, format='casa_image')
cube = cube[0,:,:]
x, y = 7047, 7342
size = 9

cube_cutout = cube[y - size:y + size, x - size:x + size]
yy, xx = cube_cutout.spatial_coordinate_map

cord = cube.world[y,x]

# print("cord (cube.world[y,x])", cord, '\n')
# print("xx, yy (cube_cutout.spatial_coordinate_map)",yy, xx, '\n')

p_init_gauss2D = models.Gaussian2D(x_mean=cord[1], y_mean=cord[0], amplitude=1 * (u.Jy/u.beam),
                                   x_stddev=(0.019) * u.arcsec, y_stddev=(0.031) * u.arcsec, theta = (np.pi/4) * u.rad)

fit_p = fitting.LevMarLSQFitter()


cube_cutout_quant = cube_cutout

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, cube_cutout_quant)

cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 ALMA Band 3 (3mm) continuum", fontsize=18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(cube_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(cube_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# Parameter Error
#
# 3.836216067e-03 2.044091978e-04
#
# 2.909170744e+02 1.454176091e-09
#
# 1.451823444e+01 1.455523159e-09
#
# 5.279267233e-06 1.077190869e-09
#
# 8.612894463e-06 1.789961061e-09
#
# 7.852487910e-01 2.868763693e-04

# %% [markdown]
# #### VLA Q-band (0.7 cm = 46.99 GHz) continuum
# `/orange/adamginsburg/w51/vla/19A-254/blue_imaging/W51_North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal4_final.image.tt0.pbcor.fits`

# %%
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.io import fits
import radio_beam
from radio_beam import Beam
import numpy as np

directory3 = '/orange/adamginsburg/w51/vla/19A-254/blue_imaging/W51_North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal4_final.image.tt0.pbcor.fits'

#cube = SpectralCube.read(directory3, format='fits')
#cube[0].header

hdul = fits.open(directory3)
hdu = hdul[0]
header = hdu.header
beam = Beam.from_fits_header(header) # I think this is right but you can look i tup
data = hdu.data * u.Unit(hdu.header['BUNIT'])

#plt.imshow(data, origin='lower', cmap='inferno')

# %%
x, y = 7345, 7544
size = 12
data_cutout = data[y - size:y + size, x - size:x + size]

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u
from astropy.wcs import WCS
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    ww = WCS(header)

ypixel_grid, xpixel_grid = np.mgrid[y - size:y + size, x - size:x + size]
xx, yy = ww.pixel_to_world_values(xpixel_grid, ypixel_grid)

xx = (xx * u.deg)
yy = (yy * u.deg)

p_init_gauss2D = models.Gaussian2D(x_mean=xx[size, size], y_mean=yy[size, size], amplitude=1 * (u.Jy/u.beam),
                                   x_stddev= (0.021) * u.arcsec, y_stddev=(0.026) * u.arcsec, theta = (np.pi/4) * u.rad)
#p_init_gauss2D.amplitude.fixed = True

fit_p = fitting.LevMarLSQFitter()

data_cutout_quant = data_cutout

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, data_cutout_quant)
    
cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 VLA Q-band (0.7 cm) continuum",fontsize = 18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(data_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(data_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# Parameter Error
#
# 1.0874127e-03 1.123486631e-04
#
# 2.909170724e+02 7.349999359e-10
#
# 1.451823333e+01 7.355606619e-10
#
# 5.832473193e-06 6.562175803e-10
#
# 7.220523623e-06 8.173703478e-10
#
# 7.851959800e-01 3.724210117e-04

# %% [markdown]
# #### VLA Ka-band ( 1 cm =  GHz) continuum
# `/orange/adamginsburg/w51/vla/19A-254/derod/W51_North_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.image.tt0.pbcor.fits`

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u

#Accessing Cube Data
cube = SpectralCube.read('/orange/adamginsburg/w51/vla/19A-254/derod/W51_North_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.image.tt0.pbcor.fits', format='fits')
cube = cube[0,:,:]
x, y = 4949, 5015
size = 5

cube_cutout = cube[y - size:y + size, x - size:x + size]
yy, xx = cube_cutout.spatial_coordinate_map

cord = cube.world[y,x]

p_init_gauss2D = models.Gaussian2D(x_mean=cord[1], y_mean=cord[0], amplitude=0.03 * (u.Jy/u.beam),
                                   x_stddev=1.111111e-5 * u.degree, y_stddev=1.111111e-5 * u.degree, theta=1.5*u.rad)

fit_p = fitting.LevMarLSQFitter()


cube_cutout_quant = cube_cutout



with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, cube_cutout_quant)


p_init_gauss2D.theta.fixed = True

cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

              
plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 VLA Ka (1 cm) continuum", fontsize=18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(cube_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(cube_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

#saveplotfig_gaussianfit()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_1 [spectral_cube.wcs_utils]
# WARNING: WCSWarning: WCS1 is missing card PV2_2 [spectral_cube.wcs_utils]
# Parameter Error
#
# 8.930578330e-04 1.013525271e-04
#
# 2.909170714e+02 6.855466525e-07
#
# 1.451823383e+01 9.664812412e-07
#
# 8.777530932e-06 1.013606589e-06
#
# 5.535689577e-06 6.413065149e-07
#
# 1.908096524e+00 1.789684558e-01

# %%
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.io import fits
import radio_beam
from radio_beam import Beam
import numpy as np

directory3 = '/orange/adamginsburg/w51/vla/19A-254/derod/W51_North_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.image.tt0.pbcor.fits'

#cube = SpectralCube.read(directory3, format='fits')
#cube[0].header

hdul = fits.open(directory3)
hdu = hdul[0]
header = hdu.header
beam = Beam.from_fits_header(header) # I think this is right but you can look i tup
data = hdu.data * u.Unit(hdu.header['BUNIT'])
#plt.imshow(data, origin='lower', cmap='inferno')

# %%
# Out:
# <Quantity [[[nan, nan, nan, ..., nan, nan, nan],
#             [nan, nan, nan, ..., nan, nan, nan],
#             [nan, nan, nan, ..., nan, nan, nan],
#             ...,
#             [nan, nan, nan, ..., nan, nan, nan],
#             [nan, nan, nan, ..., nan, nan, nan],
#             [nan, nan, nan, ..., nan, nan, nan]]] Jy / beam>

# %%
x, y = 4949, 5015
size = 7
data_cutout = data[y - size:y + size, x - size:x + size]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /scratch/local/19776337/ipykernel_36248/424966323.py in <module>
#       2 size = 7
#       3 data_cutout = data[y - size:y + size, x - size:x + size]
# ----> 4 plt.imshow(data_cutout)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (0, 14, 10000) for image data

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u
from astropy.wcs import WCS
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    ww = WCS(header)

ypixel_grid, xpixel_grid = np.mgrid[y - size:y + size, x - size:x + size]
xx, yy = ww.pixel_to_world_values(xpixel_grid, ypixel_grid)

xx = (xx * u.deg)
yy = (yy * u.deg)

p_init_gauss2D = models.Gaussian2D(x_mean=xx[size, size], y_mean=yy[size, size], amplitude=1 * (u.Jy/u.beam),
                                   x_stddev= (0.021) * u.arcsec, y_stddev=(0.026) * u.arcsec, theta = (np.pi/4) * u.rad)
#p_init_gauss2D.amplitude.fixed = True

fit_p = fitting.LevMarLSQFitter()

data_cutout_quant = data_cutout

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, data_cutout_quant)
    
cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 VLA Q-band (0.7 cm) continuum",fontsize = 18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(data_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(data_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /scratch/local/19776337/ipykernel_36248/4117936602.py in <module>
#      15
#      16 ypixel_grid, xpixel_grid = np.mgrid[y - size:y + size, x - size:x + size]
# ---> 17 xx, yy = ww.pixel_to_world_values(xpixel_grid, ypixel_grid)
#      18
#      19 xx = (xx * u.deg)
#
# ~/.local/lib/python3.8/site-packages/astropy/wcs/wcsapi/fitswcs.py in pixel_to_world_values(self, *pixel_arrays)
#     311
#     312     def pixel_to_world_values(self, *pixel_arrays):
# --> 313         world = self.all_pix2world(*pixel_arrays, 0)
#     314         return world[0] if self.world_n_dim == 1 else tuple(world)
#     315
#
# ~/.local/lib/python3.8/site-packages/astropy/wcs/wcs.py in all_pix2world(self, *args, **kwargs)
#    1344
#    1345     def all_pix2world(self, *args, **kwargs):
# -> 1346         return self._array_converter(
#    1347             self._all_pix2world, 'output', *args, **kwargs)
#    1348     all_pix2world.__doc__ = """
#
# ~/.local/lib/python3.8/site-packages/astropy/wcs/wcs.py in _array_converter(self, func, sky, ra_dec_order, *args)
#    1336             return _return_list_of_arrays(axes, origin)
#    1337
# -> 1338         raise TypeError(
#    1339             "WCS projection has {0} dimensions, so expected 2 (an Nx{0} array "
#    1340             "and the origin argument) or {1} arguments (the position in each "
#
# TypeError: WCS projection has 4 dimensions, so expected 2 (an Nx4 array and the origin argument) or 5 arguments (the position in each dimension, and the origin argument). Instead, 3 arguments were given.

# %%
header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                10000
# NAXIS2  =                10000
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.411030172474E-05
# BMIN    =   1.317552187377E-05
# BPA     =   3.874738311768E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'W51 North'
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   1.451817221939E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.909168499983E+02
# CDELT1  =  -4.166666666667E-06
# CRPIX1  =   5.001000000000E+03
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =   1.451817221939E+01
# CDELT2  =   4.166666666667E-06
# CRPIX2  =   5.001000000000E+03
# CUNIT2  = 'deg     '
# CTYPE3  = 'FREQ    '
# CRVAL3  =   3.303677897302E+10
# CDELT3  =   7.691582544997E+09
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'Hz      '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   3.646626000000E+10 /Rest Frequency (Hz)
# SPECSYS = 'LSRK    '           /Spectral reference frame
# ALTRVAL =   2.819407712066E+07 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'EVLA    '
# OBSERVER= 'Dr. Adam Ginsburg'
# DATE-OBS= '2019-08-18T04:09:43.000000'
# TIMESYS = 'UTC     '
# OBSRA   =   2.909168499983E+02
# OBSDEC  =   1.451817221939E+01
# OBSGEO-X=  -1.601156673287E+06
# OBSGEO-Y=  -5.041988986066E+06
# OBSGEO-Z=   3.554879236821E+06
# INSTRUME= 'EVLA    '
# DISTANCE=   0.000000000000E+00
# MPIPROCS=                    1
# CHNCHNKS=                    1
# MEMREQ  =        8.0466270E+00
# MEMAVAIL=        2.6652792E+02
# USEWEIGH=                    F
# DATE    = '2022-03-01T18:29:47.555607' /Date FITS file was written
# ORIGIN  = 'CASA 6.4.3-4 CASAtools:v1.0.0'
# HISTORY CASA START LOGTABLE
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::ImagePrimaryBeamCorrector::correct (
# HISTORY >file src/code/imageanalysis/ImageAnalysis/ImagePrimaryBeamCorrector.cc,
# HISTORY > line 208)'
# HISTORY History of image /blue/adamginsburg/adamginsburg/w51-imaging/W51_North_K
# HISTORY >abandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.image
# HISTORY >tt0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY taskname=tclean
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY version: 6.4.3-4 CASAtools:v1.0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY vis         = "continuum_concatenated.ms"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY selectdata  = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY field       = "W51 North"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY spw         = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY timerange   = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY uvrange     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY antenna     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY scan        = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY observation = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY intent      = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY datacolumn  = "corrected"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY imagename   = "W51_North_KabandAarray_cont_spws_continuum_cal_clean_2ter
# HISTORY >ms_robust0_selfcal2"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY imsize      = 10000
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cell        = ['0.015 arcsec']
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY phasecenter = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY stokes      = "I"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY projection  = "SIN"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY startmodel  = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY specmode    = "mfs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY reffreq     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nchan       = -1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY start       = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY width       = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY outframe    = "LSRK"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY veltype     = "radio"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restfreq    = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY interpolation = "linear"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY perchanweightdensity = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY gridder     = "standard"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY facets      = 1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psfphasecenter = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY wprojplanes = 1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY vptable     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY mosweight   = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY aterm       = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psterm      = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY wbawp       = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY conjbeams   = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cfcache     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY usepointing = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY computepastep = 360.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY rotatepastep = 360.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pointingoffsetsigdev = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pblimit     = 0.2
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY normtype    = "flatnoise"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY deconvolver = "mtmfs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY scales      = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nterms      = 2
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY smallscalebias = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restoration = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restoringbeam = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pbcor       = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY outlierfile = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY weighting   = "briggs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY robust      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY noise       = "1.0Jy"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY npixels     = 0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY uvtaper     = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY niter       = 100000
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY gain        = 0.1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY threshold   = "0.2 mJy"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nsigma      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cycleniter  = -1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cyclefactor = 1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minpsffraction = 0.05
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY maxpsffraction = 0.8
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY interactive = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY usemask     = "user"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY mask        = "w51e2w_kband_selfcal0_mask.crtf"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pbmask      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY sidelobethreshold = 3.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY noisethreshold = 5.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY lownoisethreshold = 1.5
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY negativethreshold = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY smoothfactor = 1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minbeamfrac = 0.3
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cutthreshold = 0.01
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY growiterations = 75
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY dogrowprune = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minpercentchange = -1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY verbose     = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY fastnoise   = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restart     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY savemodel   = "modelcolumn"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY calcres     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY calcpsf     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psfcutoff   = 0.35
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY parallel    = False
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::ImagePrimaryBeamCorrector::correct (
# HISTORY >file src/code/imageanalysis/ImageAnalysis/ImagePrimaryBeamCorrector.cc,
# HISTORY > line 208)'
# HISTORY End history of image /blue/adamginsburg/adamginsburg/w51-imaging/W51_Nor
# HISTORY >th_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.i
# HISTORY >age.tt0
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::ImagePrimaryBeamCorrector::correct (
# HISTORY >file src/code/imageanalysis/ImageAnalysis/ImagePrimaryBeamCorrector.cc,
# HISTORY > line 208)'
# HISTORY History of image /blue/adamginsburg/adamginsburg/w51-imaging/W51_North_K
# HISTORY >abandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.pb.tt
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY taskname=tclean
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY version: 6.4.3-4 CASAtools:v1.0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY vis         = "continuum_concatenated.ms"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY selectdata  = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY field       = "W51 North"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY spw         = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY timerange   = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY uvrange     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY antenna     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY scan        = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY observation = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY intent      = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY datacolumn  = "corrected"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY imagename   = "W51_North_KabandAarray_cont_spws_continuum_cal_clean_2ter
# HISTORY >ms_robust0_selfcal2"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY imsize      = 10000
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cell        = ['0.015 arcsec']
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY phasecenter = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY stokes      = "I"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY projection  = "SIN"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY startmodel  = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY specmode    = "mfs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY reffreq     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nchan       = -1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY start       = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY width       = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY outframe    = "LSRK"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY veltype     = "radio"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restfreq    = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY interpolation = "linear"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY perchanweightdensity = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY gridder     = "standard"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY facets      = 1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psfphasecenter = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY wprojplanes = 1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY vptable     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY mosweight   = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY aterm       = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psterm      = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY wbawp       = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY conjbeams   = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cfcache     = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY usepointing = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY computepastep = 360.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY rotatepastep = 360.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pointingoffsetsigdev = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pblimit     = 0.2
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY normtype    = "flatnoise"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY deconvolver = "mtmfs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY scales      = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nterms      = 2
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY smallscalebias = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restoration = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restoringbeam = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pbcor       = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY outlierfile = ""
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY weighting   = "briggs"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY robust      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY noise       = "1.0Jy"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY npixels     = 0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY uvtaper     = []
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY niter       = 100000
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY gain        = 0.1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY threshold   = "0.2 mJy"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY nsigma      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cycleniter  = -1
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cyclefactor = 1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minpsffraction = 0.05
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY maxpsffraction = 0.8
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY interactive = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY usemask     = "user"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY mask        = "w51e2w_kband_selfcal0_mask.crtf"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY pbmask      = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY sidelobethreshold = 3.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY noisethreshold = 5.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY lownoisethreshold = 1.5
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY negativethreshold = 0.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY smoothfactor = 1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minbeamfrac = 0.3
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY cutthreshold = 0.01
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY growiterations = 75
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY dogrowprune = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY minpercentchange = -1.0
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY verbose     = False
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY fastnoise   = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY restart     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY savemodel   = "modelcolumn"
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY calcres     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY calcpsf     = True
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY psfcutoff   = 0.35
# HISTORY 2022-02-28T20:12:05 INFO SRCCODE='::tclean'
# HISTORY parallel    = False
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::ImagePrimaryBeamCorrector::correct (
# HISTORY >file src/code/imageanalysis/ImageAnalysis/ImagePrimaryBeamCorrector.cc,
# HISTORY > line 208)'
# HISTORY End history of image /blue/adamginsburg/adamginsburg/w51-imaging/W51_Nor
# HISTORY >th_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal2.p
# HISTORY >.tt0
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::impbcor'
# HISTORY version: 6.4.3-4 CASAtools:v1.0.0
# HISTORY 2022-02-28T20:12:11 INFO SRCCODE='::impbcor'
# HISTORY impbcor(imagename="W51_North_KabandAarray_cont_spws_continuum_cal_clean_
# HISTORY >2terms_robust0_selfcal2.image.tt0", pbimage="W51_North_KabandAarray_con
# HISTORY >_spws_continuum_cal_clean_2terms_robust0_selfcal2.pb.tt0", outfile="W51
# HISTORY >North_KabandAarray_cont_spws_continuum_cal_clean_2terms_robust0_selfcal
# HISTORY >.image.tt0.pbcor", overwrite=True, box="", region="", chans="", stokes=
# HISTORY >", mask="", mode="divide", cutoff=-1.0, stretch=False)
# HISTORY CASA END LOGTABLE

# %% [markdown]
# switch the Q-band data you're using to /orange/adamginsburg/w51/vla/16B-202_W51QKa/merge/W51North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_incrementalselfcal10.image.tt0.pbcor.fits

# %%
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.io import fits
import radio_beam
from radio_beam import Beam
import numpy as np

directory3 = '/orange/adamginsburg/w51/vla/16B-202_W51QKa/merge/W51North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_incrementalselfcal10.image.tt0.pbcor.fits'

#cube = SpectralCube.read(directory3, format='fits')
#cube[0].header

hdul = fits.open(directory3)
hdu = hdul[0]
header = hdu.header
beam = Beam.from_fits_header(header) # I think this is right but you can look i tup
data = hdu.data * u.Unit(hdu.header['BUNIT'])

#plt.imshow(data, origin='lower', cmap='inferno')
header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    2
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.280000122885E-05
# BMIN    =   9.402085302605E-06
# BPA     =  -6.654223632812E+01
# BTYPE   = 'Intensity'
# OBJECT  = '        '
#
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =   1.451852416667E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.909164958333E+02
# CDELT1  =  -2.777777777778E-06
# CRPIX1  =   5.130000000000E+02
# CUNIT1  = 'deg     '
# PV2_1   =   0.000000000000E+00
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =   1.451852416667E+01
# CDELT2  =   2.777777777778E-06
# CRPIX2  =   5.130000000000E+02
# CUNIT2  = 'deg     '
# PV2_2   =   0.000000000000E+00
# TELESCOP= 'EVLA    '
# OBSERVER= 'Dr. Adam Ginsburg'
# DATE-OBS= '2016-12-26T15:45:56.999999'
# TIMESYS = 'UTC     '
# OBSRA   =   2.909164958333E+02
# OBSDEC  =   1.451852416667E+01
# OBSGEO-X=  -1.601156673287E+06
# OBSGEO-Y=  -5.041988986066E+06
# OBSGEO-Z=   3.554879236821E+06
# DATE    = '2018-05-13T19:57:00.946000' /Date FITS file was written
# ORIGIN  = 'CASA 5.3.0-126'
# HISTORY CASA START LOGTABLE
# HISTORY 2018-05-13T19:57:01 INFO SRCCODE='::image::pbcor'
# HISTORY Ran ia.pbcor
# HISTORY 2018-05-13T19:57:01 INFO SRCCODE='::image::pbcor'
# HISTORY ia.pbcor(pbimage="W51North_QbandAarray_cont_spws_continuum_cal_clean_2te
# HISTORY >rms_robust0_incrementalselfcal10.pb.tt0", outfile="W51North_QbandAarray
# HISTORY >cont_spws_continuum_cal_clean_2terms_robust0_incrementalselfcal10.image
# HISTORY >tt0.pbcor", overwrite=true, box="", region="", chans="", stokes="", mas
# HISTORY >="", mode="divide", cutoff=-1.000000, stretch=false)
# HISTORY CASA END LOGTABLE

# %%
x, y = 310, 408
size = 10

data_cutout = data[y - size:y + size, x - size:x + size]

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
from spectral_cube import SpectralCube, Projection
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy.convolution import convolve_models
from astropy import units as u
from astropy.wcs import WCS
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    ww = WCS(header)

ypixel_grid, xpixel_grid = np.mgrid[y - size:y + size, x - size:x + size]
xx, yy = ww.pixel_to_world_values(xpixel_grid, ypixel_grid)

xx = (xx * u.deg)
yy = (yy * u.deg)

p_init_gauss2D = models.Gaussian2D(x_mean=xx[size, size], y_mean=yy[size, size], amplitude=0.02 * (u.Jy/u.beam),
                                   x_stddev= (0.018) * u.arcsec, y_stddev=(0.020) * u.arcsec, theta = (np.pi/4) * u.rad)
#p_init_gauss2D.amplitude.fixed = True

fit_p = fitting.LevMarLSQFitter()

data_cutout_quant = data_cutout

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    p_gauss2D = fit_p(p_init_gauss2D, xx, yy, data_cutout_quant)
    
cov = np.diag(fit_p.fit_info['param_cov'])
errors = np.sqrt(cov)

amplitude_error=np.format_float_scientific(errors[0],precision=9)
x_mean_error=np.format_float_scientific(errors[1],precision=9)
y_mean_error=np.format_float_scientific(errors[2],precision=9)
x_stddev_error=np.format_float_scientific(errors[3],precision=9)
y_stddev_error=np.format_float_scientific(errors[4],precision=9)
theta_error=np.format_float_scientific(errors[5],precision=9)

amplitude = np.format_float_scientific(p_gauss2D.amplitude[0],precision=9)
x_mean = np.format_float_scientific(p_gauss2D.x_mean[0],precision=9)
y_mean = np.format_float_scientific(p_gauss2D.y_mean[0],precision=9)
x_stddev = np.format_float_scientific(p_gauss2D.x_stddev[0],precision=9)
y_stddev = np.format_float_scientific(p_gauss2D.y_stddev[0],precision=9)
theta = np.format_float_scientific(p_gauss2D.theta[0],precision=9)

plt.figure(figsize=(20, 6))
plt.suptitle("W51CA3 VLA Q-band (0.7 cm) continuum",fontsize = 18)

plt.subplot(1, 3, 1)
plt.title("Image")
plt.imshow(data_cutout.value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.title("Model")
plt.imshow(p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.title("Residual")
plt.imshow(data_cutout.value - p_gauss2D(xx, yy).value, origin='lower', cmap='inferno')
plt.colorbar(label='S (Jy)')

plt.show()

print("Parameter" + ' ' + 'Error' +"\n")
print(amplitude + ' ' + amplitude_error +"\n")
print(x_mean + ' ' + x_mean_error +"\n")
print(y_mean + ' ' + y_mean_error +"\n")
print(x_stddev + ' ' + x_stddev_error +"\n")
print(y_stddev + ' ' + y_stddev_error +"\n")
print(theta + ' ' + theta_error +"\n")
# Out:
# Parameter Error
#
# 4.248654727e-04 6.997815934e-05
#
# 2.909170754e+02 1.849201783e-08
#
# 1.45182353e+01 1.849201783e-08
#
# 4.984126741e-06 1.749453983e-08
#
# 5.54831977e-06 1.943837758e-08
#
# 7.938623025e-01 2.343885679e-02

# %% [markdown]
# ## FK5 ICRS Conversion

# %%
from astropy import coordinates, units as u

coordinates.SkyCoord('19:23:45.05','17:30:30', unit=(u.hour, u.deg), frame='fk5').fk5
# Out:
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (290.93770833, 17.50833333)>

# %%
from astropy import coordinates, units as u

coordinates.SkyCoord('19:23:45.05','17:30:30', unit=(u.hour, u.deg), frame='fk5').icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (290.93770209, 17.50832727)>

# %% [markdown]
# #### Finding the Coordinate System for Each FITS

# %%
directory1 = '/orange/adamginsburg/w51/FITS/W51n_cont_briggsSC_tclean.image.fits'
directory2 = '/orange/adamginsburg/w51/2017.1.00293.S/may2021_imaging/w51n.spw0thru19.14500.robust0.thr0.075mJy.mfs.I.startmod.selfcal7.image.tt0'
directory3 = '/orange/adamginsburg/w51/vla/16B-202_W51QKa/merge/W51North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_wproj_selfcal16_final.image.tt0'

ALMA_Band_6_cube = SpectralCube.read(directory1, format='casa_image')
ALMA_Band_3_cube = SpectralCube.read(directory2, format='casa_image')
VLA_QBand_cube   = SpectralCube.read(directory3, format='casa_image')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /scratch/local/18717328/ipykernel_38369/2460739600.py in <module>
#       3 directory3 = '/orange/adamginsburg/w51/vla/16B-202_W51QKa/merge/W51North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_wproj_selfcal16_final.image.tt0'
#       4
# ----> 5 ALMA_Band_6_cube = SpectralCube.read(directory1, format='casa_image')
#       6 ALMA_Band_3_cube = SpectralCube.read(directory2, format='casa_image')
#       7 VLA_QBand_cube   = SpectralCube.read(directory3, format='casa_image')
#
# ~/.local/lib/python3.8/site-packages/spectral_cube/io/core.py in __call__(self, filename, *args, **kwargs)
#     116         kwargs['target_cls'] = BaseSpectralCube
#     117         try:
# --> 118             return registry.read(BaseSpectralCube, filename, *args, **kwargs)
#     119         except IsADirectoryError:  # See note above StringWrapper
#     120             return registry.read(BaseSpectralCube, StringWrapper(filename), *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/astropy/io/registry.py in read(cls, format, cache, *args, **kwargs)
#     518
#     519         reader = get_reader(format, cls)
# --> 520         data = reader(*args, **kwargs)
#     521
#     522         if not isinstance(data, cls):
#
# ~/.local/lib/python3.8/site-packages/spectral_cube/io/casa_image.py in load_casa_image(filename, skipdata, memmap, skipvalid, skipcs, target_cls, use_dask, **kwargs)
#      60     # read in the data
#      61     if not skipdata:
# ---> 62         data = casa_image_dask_reader(filename, memmap=memmap)
#      63
#      64     # CASA stores validity of data as a mask
#
# ~/.local/lib/python3.8/site-packages/spectral_cube/io/casa_dask.py in casa_image_dask_reader(imagename, memmap, mask)
#     148     # dminfo = tb.getdminfo()
#     149     # tb.close()
# --> 150     dminfo = getdminfo(str(imagename))
#     151
#     152     # Determine whether file is big endian
#
# ~/.local/lib/python3.8/site-packages/spectral_cube/io/casa_low_level_io.py in getdminfo(filename)
#     417     """
#     418
# --> 419     with open(os.path.join(filename, 'table.f0'), 'rb') as f:
#     420
#     421         magic = f.read(4)
#
# NotADirectoryError: [Errno 20] Not a directory: '/orange/adamginsburg/w51/FITS/W51n_cont_briggsSC_tclean.image.fits/table.f0'

# %%
directory1 = '/orange/adamginsburg/w51/FITS/W51n_cont_briggsSC_tclean.image.fits'
cube = SpectralCube.read(directory1, format='fits')
cube1 = cube[0,:,:]

directory2 = '/orange/adamginsburg/w51/2017.1.00293.S/may2021_successful_imaging/w51n.spw0thru19.14500.robust0.thr0.075mJy.mfs.I.startmod.selfcal7.image.tt0.pbcor'
cube = SpectralCube.read(directory2, format='casa_image')
cube2 = cube[0,:,:]

directory3 = '/orange/adamginsburg/w51/vla/16B-202_W51QKa/merge/W51North_QbandAarray_cont_spws_continuum_cal_clean_2terms_robust0_wproj_selfcal16_final.image.tt0.pbcor.fits'
hdul = fits.open(directory3)
hdu = hdul[0]
header = hdu.header
beam = Beam.from_fits_header(header) # I think this is right but you can look i tup
data = hdu.data * u.Unit(hdu.header['BUNIT'])
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.io.core]

# %%
x, y = 3295, 3580
size = 100

cube_cutout1 = cube1[y - size:y + size, x - size:x + size]

# %%
x, y = 7047, 7342
size = 50

cube_cutout2 = cube2[y - size:y + size, x - size:x + size]

# %%
x, y = 3922, 4023
size = 50

data_cutout = data[y - size:y + size, x - size:x + size]

# %%
plt.imshow(cube_cutout1.value, origin='lower', cmap='inferno')

# %%
plt.imshow(cube_cutout2.value, origin='lower', cmap='inferno')

# %%
plt.imshow(data_cutout.value, origin='lower', cmap='inferno')

# %%
plt.imshow(cube_cutout2.value, origin='lower', cmap='inferno')
