# %% [markdown]
# ### W51North_spw_44_Qband_rough_04.image.fits

# %%
import pyspeckit
from spectral_cube import SpectralCube

#Import data
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_44_Qband_rough_04.image.fits', format='fits')

import pylab as pl
pl.style.use('default')

#Pixel location (x,y)
y, x = 755, 737

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
sp.plotter(color='black')

#Saving methods
field='W51North'
spw=48
directory1 = '/orange/adamginsburg/w51/vla/19A-254/derod/gaussianplots/'

#Save gaussianfit
def saveplotfig_gaussianfit():
    answer = None 
    while answer not in ("yes", "no"): 
        answer = input("Save the gaussian fit (yes or no)?") 
        if answer == "yes": 
            sp.plotter.savefig(directory1+field+'_spw_'+str(spw)+'_GaussianFit1D_V1.3.png')
            print('File saved.')
        
#Save residual        
def saveplotfig_residual():
    answer = None 
    while answer not in ("yes", "no"): 
        answer = input("Save the residual (yes or no)?") 
        if answer == "yes": 
            pl.savefig(directory1+field+'_spw_'+str(spw)+'_GaussianFit1D_residual_V1.3.png')
            print('File saved.')
            
from astropy import units as u

# #Plot the gassiuan fits in to each peak in the spectra
fig = pl.figure(figsize=(12,8))
sp.plotter(color='black', xmin=43.114*u.GHz, xmax=43.116*u.GHz, figure=fig)

sp.specfit(guesses=[0.06, 43.11485e9, 0.00001e9], linewidth=1.5)
sp.specfit(guesses=[0.06, 43.11485e9, 0.00001e9], linewidth=1.5)

#sp.specfit.plot_fit(lw=1.0, composite_lw=1.8, show_components=True)
saveplotfig_gaussianfit()

#Plot the residuals of the gassiuan fits
# sp.specfit.plotresiduals(color='black', zeroline=True)
#pl.ylim(-0.05, 0.05)
saveplotfig_residual()
# Out:
# block_reduce was moved to the astropy.nddata.blocks module.  Please update your import statement.
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# Save the gaussian fit (yes or no)? no
# Save the residual (yes or no)? no

# %% [markdown]
# ### W51North_spw_25_Qband_rough_01.image.fits

# %%
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_25_Qband_rough_01.image.fits', format='fits')
y, x = 838, 848

fig = pl.figure(figsize=(12,8))
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
sp.plotter(color='black')

sp.plotter(color='black', xmin=48.988*u.GHz, xmax=48.992*u.GHz, figure=fig)

sp.specfit(guesses=[0.06, 48.98957e9, 0.00001e9], linewidth=1.5)
sp.specfit(guesses=[0.06, 48.98957e9, 0.00001e9], linewidth=1.5)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.

# %% [markdown]
# ### W51North_spw_29_Qband_rough_01.image.fits

# %%
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_29_Qband_rough_01.image.fits', format='fits')
y, x = 728, 788

fig = pl.figure(figsize=(12,8))
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])
sp.plotter(color='black')

sp.plotter(color='black', xmin=49.8421*u.GHz, xmax=49.844*u.GHz, figure=fig)

sp.specfit(guesses=[160, 49.8426e9, 0.0001e9], linewidth=1.5)
sp.specfit(guesses=[160, 49.8426e9, 0.0001e9], linewidth=1.5)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.

# %% [markdown]
# ### W51North_spw_39_Qband_rough_01.image.fits

# %%
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_39_Qband_rough_01.image.fits', format='fits')

y, x = 755, 744

fig = pl.figure(figsize=(12,8))
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])

sp.plotter(color='black')
sp.plotter(color='black', xmin=42.80975*u.GHz, xmax=42.81050*u.GHz, figure=fig)

sp.specfit(guesses=[0.05, 42.81006e9, 0.00001e9, 0.08, 42.81015e9, 0.00001e9], linewidth=1.5)
sp.specfit(guesses=[0.05, 42.81006e9, 0.00001e9, 0.08, 42.81015e9, 0.00001e9], linewidth=1.5)
sp.specfit.plot_fit(lw=1.0, composite_lw=1.0, show_components=True)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.

# %%
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_39_Qband_rough_01.image.fits', format='fits')

y, x = 754, 740

sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])

#sp.plotter(color='black')
sp.plotter(color='black', xmin=42.8115*u.GHz, xmax=42.8125*u.GHz, figure=fig)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.

# %%
cube = SpectralCube.read('/home/dealderod/derod/W51North_spw_39_Qband_rough_01.image.fits', format='fits')

y, x = 489, 809
sp = pyspeckit.Spectrum(xarr=cube.spectral_axis, data=cube[:, y, x])

#sp.plotter(color='black')
fig = pl.figure(figsize=(12,8))

sp.plotter(color='black', xmin=42.81830*u.GHz, xmax=42.8195*u.GHz, figure=fig)

sp.specfit(guesses=[0.05, 42.81885e9, 0.00001e9], linewidth=1.5)
sp.specfit(guesses=[0.05, 42.81885e9, 0.00001e9], linewidth=1.5)
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
