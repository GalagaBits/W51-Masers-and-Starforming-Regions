# %%
import pyspeckit
from spectral_cube import SpectralCube
from astropy import units as u
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('default')
import pandas as pd
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
cd /Volumes/GalagaResearch/Developer/masers/W51/FITS/original/
# Out:
# /Volumes/GalagaResearch/Developer/masers/W51/FITS/original

# %%
cube_76 = SpectralCube.read('W51North_spw_6_corrected50_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_76 = cube_76.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 22.924940*u.GHz)
cube_76_t = cube_76.to(u.K)/10**4


y, x = 415, 344

sp_76 = pyspeckit.Spectrum(xarr=cube_76.spectral_axis, data=cube_76[:, y, x])
sp_76_t = pyspeckit.Spectrum(xarr=cube_76_t.spectral_axis, data=cube_76_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_77 = SpectralCube.read('W51North_spw_28_corrected40_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_77 = cube_77.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 25.715182*u.GHz)
cube_77_t = cube_77.to(u.K)/10**4

y, x = 415, 344

sp_77 = pyspeckit.Spectrum(xarr=cube_77.spectral_axis, data=cube_77[:, y, x])
sp_77_t = pyspeckit.Spectrum(xarr=cube_77_t.spectral_axis, data=cube_77_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_119 = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_119.allow_huge_operations=True
cube_119 = cube_119.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.070739*u.GHz)
cube_119_t = cube_119.to(u.K)/10**4

y, x = 415, 344

sp_119 = pyspeckit.Spectrum(xarr=cube_119.spectral_axis, data=cube_119[:, y, x])
sp_119_t = pyspeckit.Spectrum(xarr=cube_119_t.spectral_axis, data=cube_119_t[:, y, x])


cube_119_1 = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_119_1.allow_huge_operations=True
cube_119_1 = cube_119_1.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.070739*u.GHz)
cube_119_1_t = cube_119_1.to(u.K)/10**4

y, x = 413, 407

sp_119_1 = pyspeckit.Spectrum(xarr=cube_119_1.spectral_axis, data=cube_119_1[:, y, x])
sp_119_1_t = pyspeckit.Spectrum(xarr=cube_119_1_t.spectral_axis, data=cube_119_1_t[:, y, x])


cube_119_2 = SpectralCube.read('W51North_spw_41_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_119_2.allow_huge_operations=True
cube_119_2 = cube_119_2.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.070739*u.GHz)
cube_119_2_t = cube_119_2.to(u.K)/10**4

y, x = 397, 365

sp_119_2 = pyspeckit.Spectrum(xarr=cube_119_2.spectral_axis, data=cube_119_2[:, y, x])
sp_119_2_t = pyspeckit.Spectrum(xarr=cube_119_2_t.spectral_axis, data=cube_119_2_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_53 = SpectralCube.read('W51North_spw_44_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_53 = cube_53.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.285275*u.GHz)

y, x = 356, 638

sp_53 = pyspeckit.Spectrum(xarr=cube_53.spectral_axis, data=cube_53[:, y, x])

fig, ax = plt.subplots(figsize=(6,4))

sp_53.plotter(axis=ax, color='tab:cyan',clear=False,figure=fig, label='(7,6)')

axt = ax.twinx()

cube_53_t = cube_53.to(u.K)/10**4
sp_53_t = pyspeckit.Spectrum(xarr=cube_53_t.spectral_axis, data=cube_53_t[:, y, x])
sp_53_t.plotter(axis=axt, color='tab:cyan',clear=False,figure=fig, label='(7,6)')
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
sp_53 = pyspeckit.Spectrum(xarr=cube_53.spectral_axis, data=cube_53[:, y, x])
# Out:
# WARNING: No header given.  Creating an empty one.

# %%
sp_53_t.data
# Out:
# masked_array(data=[ 3.55117957e-01,  4.37720846e-01,  4.71213218e-01,
#                     7.15111932e-01,  8.19971096e-01,  7.53767112e-01,
#                     3.43199589e-01,  7.99693694e-02,  3.93229826e-01,
#                     6.56339133e-01,  3.20569182e-01,  1.89107793e-01,
#                     2.88745100e-01,  1.67497345e-01,  1.28901819e-01,
#                     3.10162190e-01,  1.84988711e-04,  1.67554209e-01,
#                     1.14343317e-01,  2.09508157e-01,  3.46302792e-01,
#                     5.40102760e-01,  8.27521442e-01,  6.34554834e-01,
#                     5.82212609e-01,  3.67598530e-01,  1.26705130e-01,
#                     1.68237017e-01,  5.60032567e-01,  4.79385499e-01,
#                     5.32889655e-01,  3.62294275e-01,  1.30951415e-01,
#                     3.43327878e-01,  6.32635333e-01,  5.03972028e-01,
#                     4.76366015e-01,  6.80490260e-01,  4.58878810e-01,
# ...

# %%
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

# %%
fig, ax = plt.subplots(3,1,figsize=(6,4), sharex=True)

axt_0 = ax[0].twinx()
axt_1 = ax[1].twinx()
axt_2 = ax[2].twinx()

sp_76.plotter(axis=ax[0],color='tab:cyan',clear=False,figure=fig, label='(7,6)')
sp_77.plotter(axis=ax[1],color='tab:olive',clear=False,figure=fig, label='(7,7)')
sp_119.plotter(axis=ax[2],color='tab:pink',clear=False,figure=fig, label='(11,9)')

sp_76_t.plotter(axis=axt_0, color='tab:cyan',clear=False,figure=fig, )
sp_77_t.plotter(axis=axt_1, color='tab:olive',clear=False,figure=fig,)
sp_119_t.plotter(axis=axt_2, color='tab:pink',clear=False,figure=fig, )

ax[0].legend()
ax[1].legend()
ax[2].legend()

ax[0].text(0.05,.75,"CA3",fontsize = 16, weight='bold',transform=ax[0].transAxes)

ax[0].minorticks_on()
ax[0].tick_params(axis="both",direction="in",color = 'black',which='both')

ax[1].minorticks_on()
ax[1].tick_params(axis="both",direction="in",color = 'black',which='both')

ax[2].minorticks_on()
ax[2].tick_params(axis="both",direction="in",color = 'black',which='both')

axt_0.minorticks_on()
axt_0.tick_params(axis="both",direction="in",color = 'black',which='both')

axt_1.minorticks_on()
axt_1.tick_params(axis="both",direction="in",color = 'black',which='both')

axt_2.minorticks_on()
axt_2.tick_params(axis="both",direction="in",color = 'black',which='both')

ax[0].set_ylabel("")
ax[2].set_ylabel("")

axt_0.set_ylabel("")
axt_2.set_ylabel("")
plt.xlim(42,56)

yticks_t2 = axt_2.yaxis.get_major_ticks()
yticks_t2[3].set_visible(False)

plt.xlabel('$V_{LSR}$ (km s$^{-1}$)')
ax[1].set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize=14)
axt_1.set_ylabel("$T_B$ ($10^{4}$ $K$)",fontsize =14)

ax[2].set_xlabel('$V_{LSR}$ (km s$^{-1}$)', fontsize=14)

fig.subplots_adjust(0,0,1,1,0,0)

# %%
cube_53 = SpectralCube.read('W51North_spw_44_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_53 = cube_53.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.285275*u.GHz)
cube_53_t = cube_53.to(u.K)/10**4

y, x = 356, 638

sp_53 = pyspeckit.Spectrum(xarr=cube_53.spectral_axis, data=cube_53[:, y, x])
sp_53_t = pyspeckit.Spectrum(xarr=cube_53_t.spectral_axis, data=cube_53_t[:, y, x])

cube_53_1 = SpectralCube.read('W51North_spw_44_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_53_1 = cube_53_1.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 21.285275*u.GHz)
cube_53_1_t = cube_53.to(u.K)/10**4

y, x = 358, 630

sp_53_1 = pyspeckit.Spectrum(xarr=cube_53_1.spectral_axis, data=cube_53_1[:, y, x])
sp_53_1_t = pyspeckit.Spectrum(xarr=cube_53_1_t.spectral_axis, data=cube_53_1_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_62 = SpectralCube.read('W51North_spw_50_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_62 = cube_62.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 18.884695*u.GHz)
cube_62_t = cube_62.to(u.K)/10**4

y, x = 359, 637

sp_62 = pyspeckit.Spectrum(xarr=cube_62.spectral_axis, data=cube_62[:, y, x])
sp_62_t = pyspeckit.Spectrum(xarr=cube_62_t.spectral_axis, data=cube_62_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_63 = SpectralCube.read('W51North_spw_56_corrected_40_aug_02.fits', format='fits')
cube_63.allow_huge_operations=True
cube_63 = cube_63.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 19.757538*u.GHz)
cube_63_t = cube_63.to(u.K)/10**4

y, x = 356, 638

sp_63 = pyspeckit.Spectrum(xarr=cube_63.spectral_axis, data=cube_63[:, y, x])
sp_63_t = pyspeckit.Spectrum(xarr=cube_63_t.spectral_axis, data=cube_63_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_63_1 = SpectralCube.read('W51North_spw_56_corrected_40_aug_02.fits', format='fits')
cube_63_1.allow_huge_operations=True
cube_63_1 = cube_63_1.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 19.757538*u.GHz)
cube_63_1_t = cube_63_t.to(u.K)/10**4

y, x = 358, 630

sp_63_1 = pyspeckit.Spectrum(xarr=cube_63_1.spectral_axis, data=cube_63_1[:, y, x])
sp_63_1_t = pyspeckit.Spectrum(xarr=cube_63_1_t.spectral_axis, data=cube_63_1_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_74 = SpectralCube.read('W51North_spw_53_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_74.allow_huge_operations=True
cube_74 = cube_74.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 19.218465*u.GHz)
cube_74_t = cube_74.to(u.K)/10**4

y, x = 358, 637

sp_74 = pyspeckit.Spectrum(xarr=cube_74.spectral_axis, data=cube_74[:, y, x])
sp_74_t = pyspeckit.Spectrum(xarr=cube_74_t.spectral_axis, data=cube_74_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_75 = SpectralCube.read('W51North_spw_38_corrected6_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_75 = cube_75.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 20.80483*u.GHz)
cube_75_t = cube_75.to(u.K)/10**4

y, x = 358, 637

sp_75 = pyspeckit.Spectrum(xarr=cube_75.spectral_axis, data=cube_75[:, y, x])
sp_75_t = pyspeckit.Spectrum(xarr=cube_75_t.spectral_axis, data=cube_75_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_85 = SpectralCube.read('W51North_spw_48_corrected2_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_85 = cube_85.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 18.808507*u.GHz)
cube_85_t = cube_85.to(u.K)/10**4

y, x = 358, 637

sp_85 = pyspeckit.Spectrum(xarr=cube_85.spectral_axis, data=cube_85[:, y, x])
sp_85_t = pyspeckit.Spectrum(xarr=cube_85_t.spectral_axis, data=cube_85_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
cube_98 = SpectralCube.read('W51North_spw_8_corrected21_aug_02_ICRS_CRVAL_CA3_crval_change.fits', format='fits')
cube_98.allow_huge_operations=True
cube_98 = cube_98.with_spectral_unit(u.km/u.s, velocity_convention='radio', rest_value = 23.657471*u.GHz)
cube_98_t = cube_98.to(u.K) /10**4

y, x = 358, 637

sp_98 = pyspeckit.Spectrum(xarr=cube_98.spectral_axis, data=cube_98[:, y, x])
sp_98_t = pyspeckit.Spectrum(xarr=cube_98_t.spectral_axis, data=cube_98_t[:, y, x])
# Out:
# Cube is a Stokes cube, returning spectral cube for I component
# WARNING: No header given.  Creating an empty one.
# WARNING: No header given.  Creating an empty one.

# %%
fig, ax= plt.subplots(7,1,figsize=(6,8),sharex=True,)

sp_53_1.plotter(axis=ax[0], color='tab:blue', clear=False, figure=fig,)
sp_53.plotter(axis=ax[0], color='tab:blue', figure=fig,clear=False,label='(5,3)',)
# sp_53_2.plotter(color='tab:blue', clear=False,figure=fig,)

sp_62.plotter(axis=ax[1],color='tab:orange',clear=False,figure=fig,label='(6,2)')
sp_63_1.plotter(axis=ax[2],color='tab:green',clear=False,figure=fig,)
sp_63.plotter(axis=ax[2],color='tab:green',clear=False,figure=fig,label='(6,3)')

sp_74.plotter(axis=ax[3], color='tab:red',clear=False,figure=fig,label='(7,4)')
sp_75.plotter(axis=ax[4],color='tab:purple',clear=False,figure=fig,label='(7,5)')
sp_85.plotter(axis=ax[5],color='tab:gray',clear=False,figure=fig,label='(8,5)')
sp_98.plotter(axis=ax[6],color='tab:brown',clear=False,figure=fig,label='(9,8)')


axt_0 = ax[0].twinx()
axt_1 = ax[1].twinx()
axt_2 = ax[2].twinx()
axt_3 = ax[3].twinx()
axt_4 = ax[4].twinx()
axt_5 = ax[5].twinx()
axt_6 = ax[6].twinx()

sp_53_1_t.plotter(axis=axt_0, color='tab:blue', clear=False, figure=fig,)
sp_53_t.plotter(axis=axt_0, color='tab:blue', figure=fig,clear=False,label='(5,3)',)
# sp_53_2.plotter(color='tab:blue', clear=False,figure=fig,)

sp_62_t.plotter(axis=axt_1,color='tab:orange',clear=False,figure=fig,label='(6,2)')
sp_63_1_t.plotter(axis=axt_2,color='tab:green',clear=False,figure=fig,)
sp_63_t.plotter(axis=axt_2,color='tab:green',clear=False,figure=fig,label='(6,3)')

sp_74_t.plotter(axis=axt_3, color='tab:red',clear=False,figure=fig,label='(7,4)')
sp_75_t.plotter(axis=axt_4,color='tab:purple',clear=False,figure=fig,label='(7,5)')
sp_85_t.plotter(axis=axt_5,color='tab:gray',clear=False,figure=fig,label='(8,5)')
sp_98_t.plotter(axis=axt_6,color='tab:brown',clear=False,figure=fig,label='(9,8)')



ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
ax[4].legend()
ax[5].legend()
ax[6].legend()

ax[0].set_xlabel('')
ax[1].set_xlabel('')
ax[2].set_xlabel('')
ax[3].set_xlabel('')
ax[4].set_xlabel('')
ax[5].set_xlabel('')
ax[6].set_xlabel('')

ax[0].set_ylabel('')
ax[1].set_ylabel('')
ax[2].set_ylabel('')
# ax[3].set_ylabel('')
ax[4].set_ylabel('')
ax[5].set_ylabel('')
ax[6].set_ylabel('')

axt_0.set_ylabel('')
axt_1.set_ylabel('')
axt_2.set_ylabel('')
# ax[3].set_ylabel('')
axt_4.set_ylabel('')
axt_5.set_ylabel('')
axt_6.set_ylabel('')

ax[0].minorticks_on()
ax[1].minorticks_on()
ax[2].minorticks_on()
ax[3].minorticks_on()
ax[4].minorticks_on()
ax[5].minorticks_on()
ax[6].minorticks_on()

axt_0.minorticks_on()
axt_1.minorticks_on()
axt_2.minorticks_on()
axt_3.minorticks_on()
axt_4.minorticks_on()
axt_5.minorticks_on()
axt_6.minorticks_on()

ax[0].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[1].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[2].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[3].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[4].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[5].tick_params(axis="both",direction="in",color = 'black',which='both')
ax[6].tick_params(axis="both",direction="in",color = 'black',which='both')

axt_0.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_1.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_2.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_3.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_4.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_5.tick_params(axis="both",direction="in",color = 'black',which='both')
axt_6.tick_params(axis="both",direction="in",color = 'black',which='both')

# loc = plticker.MultipleLocator(base=1.0) # this locator puts ticks at regular intervals
# # ax[0].xaxis.set_major_locator(loc)
# ax[0].minorticks_on()
# ax[0].tick_params(axis='y', which='minor',)

plt.text(0.05,.7,"d2",fontsize = 16, weight='bold',transform=ax[0].transAxes)
plt.xlim(50,60)
#          )
# plt.ylim(0,0.2)

plt.xlabel('$V_{LSR}$ (km s$^{-1}$)', fontsize=14)
ax[3].set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize=14)
axt_3.set_ylabel("$T_B$ ($10^{4}$ $K$)", fontsize=14)
axt_3.yaxis.labelpad = 20
#plt.tight_layout()
ax[6].set_xlabel('$V_{LSR}$ (km s$^{-1}$)', fontsize=14)

yticks_t1 = axt_1.yaxis.get_major_ticks()
yticks_t1[3].set_visible(False)

yticks_2 = ax[2].yaxis.get_major_ticks()
yticks_2[1].set_visible(False)

yticks_6 = ax[6].yaxis.get_major_ticks()
yticks_6[3].set_visible(False)

fig.subplots_adjust(0,0,1,1,0,0)

# %%
fig, ax= plt.subplots(figsize=(8,4), sharex=True)

axt = ax.twinx()
sp_119_2.plotter(axis = ax,color='red',clear=False,figure=fig, label='(11,9) $red$')
sp_119_1.plotter(axis = ax, color='blue',clear=False,figure=fig, label='(11,9) $blue$')

sp_119_2_t.plotter(axis=axt, color='red',clear=False,figure=fig,)
sp_119_1_t.plotter(axis=axt, color='blue',clear=False,figure=fig, )



ax.text(0.05,.85,"W51 North",fontsize = 16, weight='bold',transform=ax.transAxes)
ax.vlines(60, -1,1, linestyles='--', linewidth=1, alpha=0.5, colors='black')
plt.xlim(56,66)

ax.minorticks_on()
axt.minorticks_on()

ax.tick_params(axis="both",direction="in",color = 'black',which='both')
axt.tick_params(axis="both",direction="in",color = 'black',which='both')

ax.legend(title='NH$_3$')
ax.set_xlabel('$V_{LSR}$ (km s$^{-1}$)',fontsize=14)
ax.set_ylabel("$S$ (Jy beam$^{-1}$)",fontsize=14)
axt.set_ylabel("$T_B$ ($10^{4}$ $K$)",fontsize =14)
# Out:
# Text(4464.666666666666, 0.5, '$T_B$ ($10^{4}$ $K$)')
