# %% [markdown]
# # Variability Plots

# %%
import matplotlib.pyplot as plt
import pandas as pd
from astropy.time import Time
import numpy as np

plt.rcParams['figure.dpi'] = 400
plt.rcParams['savefig.dpi'] = 400

# %%
df = pd.read_csv('/orange/adamginsburg/w51/vla/19A-254/derod/W51-Masers-and-Starforming-Regions/notebooks/ammonia_Total.csv')

# %%
epoch = '2019-08-02T00:00:00'
t = Time(epoch,format='isot',scale='utc')
df['epoch'] = t
df['epoch_year'] = t.decimalyear

# %%
from astropy.table import Table
tbl = Table.read('w51d.tex', format='latex')[2:]

epoch_2 = tbl['Epoch']

# for x in epoch_2:
epoch_2 = Time(epoch_2,format='isot',scale='utc')

VLS = list(tbl['VLSR'])
VLSR = []
for x in VLS:
    VLSR.append(float(x))
        
S_flux = list(tbl['$S$'])
S = []
for x in S_flux:
    S.append(float(x))
    
S_error = [0.006,0.005,0.002,0.005,0.007,0.005,0.023,0.006,0.005,0.006,0.006,0.004,0.006,0.004,0.006,0.006,0.005,0.004]
df['S_error'] = S_error
# Out:
# /scratch/local/16076467/ipykernel_1603870/3328153548.py:12: UserWarning: Warning: converting a masked element to nan.
#   VLSR.append(float(x))
# /scratch/local/16076467/ipykernel_1603870/3328153548.py:17: UserWarning: Warning: converting a masked element to nan.
#   S.append(float(x))

# %%
epochd2 = []
epochd2 = np.append(epochd2,(df.epoch_year[0],
df.epoch_year[1],
df.epoch_year[2],
df.epoch_year[3],
df.epoch_year[4],
df.epoch_year[5],
df.epoch_year[6],
df.epoch_year[14],
epoch_2.decimalyear[1],
epoch_2.decimalyear[0],
epoch_2.decimalyear[2],
epoch_2.decimalyear[4],
epoch_2.decimalyear[5],
epoch_2.decimalyear[26]))

VLSRd2 = []
VLSRd2 = np.append(VLSRd2,(df.vlsr_kms[0],
df.vlsr_kms[1],
df.vlsr_kms[2],
df.vlsr_kms[3],
df.vlsr_kms[4],
df.vlsr_kms[5],
df.vlsr_kms[6],
df.vlsr_kms[14],
VLSR[1],
VLSR[0],
VLSR[2],
VLSR[4],
VLSR[5],
VLSR[26]))

# %%
# CA3 varibility data

a = list(df.epoch_year[7:10])
b = list(df.epoch_year[10:13])
c = df.epoch_year[15]
d = list(epoch_2.decimalyear[9:11])
e = list(epoch_2.decimalyear[19:24])
f = epoch_2.decimalyear[32]
ab = a+b
epoch = list(np.append(ab,c))
epoch = epoch + d + e
epoch = list(np.append(epoch,f))
epoch

a = list(df.vlsr_kms[7:10])
b = list(df.vlsr_kms[10:13])
c = df.vlsr_kms[15]
d = VLSR[9:11]
e = VLSR[19:24]
f = VLSR[32]
ab = a+b
V = list(np.append(ab,c))
V = V + d + e
V = list(np.append(V,f))
V, epoch
# Out:
# ([51.5238986239,
#   48.9084722979,
#   47.6007591348,
#   49.9203663095,
#   47.5887284623,
#   46.4229095386,
#   47.5069724542,
#   46.02,
#   47.55,
#   45.6,
#   46.08,
#   45.66,
#   47.29,
#   49.92,
#   47.12],
#  [2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2019.5835616438355,
#   2008.8142076502731,
#   2012.2568306010928,
#   2008.808743169399,
#   2008.808743169399,
#   2008.8142076502731,
#   2012.2568306010928,
#   2012.2568306010928,
#   2012.2568306010928])

# %%
df_Zhang2022 = pd.read_csv('/orange/adamginsburg/w51/vla/19A-254/derod/W51-Masers-and-Starforming-Regions/notebooks/apjsac60a0t2_mrt.csv')

df_Zhang2022[142:149]
t_4 = df_Zhang2022['Date'][142:149].astype(str)
vlsr = df_Zhang2022['M_V_c'][142:149].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][142:149].astype(float)
S = df_Zhang2022['S_p'][142:149].astype(float)
S_error = df_Zhang2022['S_p_error'][142:149].astype(float)

Zhang2022_7c6_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c6_time.append(t.decimalyear)

Zhang2022_7c6_vlsr = []
for i in vlsr:
    Zhang2022_7c6_vlsr.append(i)

Zhang2022_7c6_vlsr_error = []
for i in vlsrerror:
    Zhang2022_7c6_vlsr_error.append(i)

Zhang2022_7c6_S = []
for i in S:
    Zhang2022_7c6_S.append(i)

Zhang2022_7c6_S_error = []
for i in S_error:
    Zhang2022_7c6_S_error.append(i)

df_Zhang2022[107:109]
t_4 = df_Zhang2022['Date'][107:109].astype(str)
vlsr = df_Zhang2022['M_V_c'][107:109].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][107:109].astype(float)
S = df_Zhang2022['S_p'][107:109].astype(float)
S_error = df_Zhang2022['S_p_error'][107:109].astype(float)

Zhang2022_11c9_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_11c9_time.append(t.decimalyear)

Zhang2022_11c9_vlsr = []
for i in vlsr:
    Zhang2022_11c9_vlsr.append(i)

Zhang2022_11c9_vlsr_error = []
for i in vlsrerror:
    Zhang2022_11c9_vlsr_error.append(i)

Zhang2022_11c9_S = []
for i in S:
    Zhang2022_11c9_S.append(i)

Zhang2022_11c9_S_error = []
for i in S_error:
    Zhang2022_11c9_S_error.append(i)

df_Zhang2022[194:199]
t_4 = df_Zhang2022['Date'][194:199].astype(str)
vlsr = df_Zhang2022['M_V_c'][194:199].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][194:199].astype(float)
S = df_Zhang2022['S_p'][194:199].astype(float)
S_error = df_Zhang2022['S_p_error'][194:199].astype(float)

Zhang2022_7c7_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c7_time.append(t.decimalyear)

Zhang2022_7c7_vlsr = []
for i in vlsr:
    Zhang2022_7c7_vlsr.append(i)

Zhang2022_7c7_vlsr_error = []
for i in vlsrerror:
    Zhang2022_7c7_vlsr_error.append(i)

Zhang2022_7c7_S = []
for i in S:
    Zhang2022_7c7_S.append(i)

Zhang2022_7c7_S_error = []
for i in S_error:
    Zhang2022_7c7_S_error.append(i)

df_Zhang2022[50:54]
t_4 = df_Zhang2022['Date'][50:54].astype(str)
vlsr = df_Zhang2022['M_V_c'][50:54].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][50:54].astype(float)
S = df_Zhang2022['S_p'][50:54].astype(float)
S_error = df_Zhang2022['S_p_error'][50:54].astype(float)

Zhang2022_6c2_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_6c2_time.append(t.decimalyear)

Zhang2022_6c2_vlsr = []
for i in vlsr:
    Zhang2022_6c2_vlsr.append(i)

Zhang2022_6c2_vlsr_error = []
for i in vlsrerror:
    Zhang2022_6c2_vlsr_error.append(i)
    
Zhang2022_6c2_S = []
for i in S:
    Zhang2022_6c2_S.append(i)

Zhang2022_6c2_S_error = []
for i in S_error:
    Zhang2022_6c2_S_error.append(i)

df_Zhang2022[58:65]
t_4 = df_Zhang2022['Date'][58:65].astype(str)
vlsr = df_Zhang2022['M_V_c'][58:65].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][58:65].astype(float)
S = df_Zhang2022['S_p'][58:65].astype(float)
S_error = df_Zhang2022['S_p_error'][58:65].astype(float)

Zhang2022_6c3_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_6c3_time.append(t.decimalyear)

Zhang2022_6c3_vlsr = []
for i in vlsr:
    Zhang2022_6c3_vlsr.append(i)

Zhang2022_6c3_vlsr_error = []
for i in vlsrerror:
    Zhang2022_6c3_vlsr_error.append(i)
    
Zhang2022_6c3_S = []
for i in S:
    Zhang2022_6c3_S.append(i)

Zhang2022_6c3_S_error = []
for i in S_error:
    Zhang2022_6c3_S_error.append(i)

df_Zhang2022[157:162]
t_4 = df_Zhang2022['Date'][157:162].astype(str)
vlsr = df_Zhang2022['M_V_c'][157:162].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][157:162].astype(float)
S = df_Zhang2022['S_p'][157:162].astype(float)
S_error = df_Zhang2022['S_p_error'][157:162].astype(float)

Zhang2022_5c3_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_5c3_time.append(t.decimalyear)

Zhang2022_5c3_vlsr = []
for i in vlsr:
    Zhang2022_5c3_vlsr.append(i)

Zhang2022_5c3_vlsr_error = []
for i in vlsrerror:
    Zhang2022_5c3_vlsr_error.append(i)
    
Zhang2022_5c3_S = []
for i in S:
    Zhang2022_5c3_S.append(i)

Zhang2022_5c3_S_error = []
for i in S_error:
    Zhang2022_5c3_S_error.append(i)

df_Zhang2022[137:144]
t_4 = df_Zhang2022['Date'][137:144].astype(str)
vlsr = df_Zhang2022['M_V_c'][137:144].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][137:144].astype(float)
S = df_Zhang2022['S_p'][137:144].astype(float)
S_error = df_Zhang2022['S_p_error'][137:144].astype(float)

Zhang2022_7c5_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c5_time.append(t.decimalyear)

Zhang2022_7c5_vlsr = []
for i in vlsr:
    Zhang2022_7c5_vlsr.append(i)

Zhang2022_7c5_vlsr_error = []
for i in vlsrerror:
    Zhang2022_7c5_vlsr_error.append(i)
    
Zhang2022_7c5_S = []
for i in S:
    Zhang2022_7c5_S.append(i)

Zhang2022_7c5_S_error = []
for i in S_error:
    Zhang2022_7c5_S_error.append(i)

df_Zhang2022[159:164]
t_4 = df_Zhang2022['Date'][159:164].astype(str)
vlsr = df_Zhang2022['M_V_c'][159:164].astype(float)
vlsrerror = df_Zhang2022['M_V_c_error'][159:164].astype(float)
S = df_Zhang2022['S_p'][159:164].astype(float)
S_error = df_Zhang2022['S_p_error'][159:164].astype(float)

Zhang2022_9c8_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_9c8_time.append(t.decimalyear)

Zhang2022_9c8_vlsr = []
for i in vlsr:
    Zhang2022_9c8_vlsr.append(i)

Zhang2022_9c8_vlsr_error = []
for i in vlsrerror:
    Zhang2022_9c8_vlsr_error.append(i)
    
Zhang2022_9c8_S = []
for i in S:
    Zhang2022_9c8_S.append(i)

Zhang2022_9c8_S_error = []
for i in S_error:
    Zhang2022_9c8_S_error.append(i)

# %%
## Upper Limit
## 7,4

df_Zhang2022[54:58]
t_4 = df_Zhang2022['Date'][54:58].astype(str)
qvlsr = df_Zhang2022['Q_V_c'][54:58].astype(float)
qvlsrerror = df_Zhang2022['Q_V_c_error'][54:58].astype(float)
S = df_Zhang2022['S_p'][54:58].astype(float)
S_error = df_Zhang2022['S_p_error'][54:58].astype(float)

Zhang2022_7c4_time = []
for i in t_4:
    t = Time(i)
    Zhang2022_7c4_time.append(t.decimalyear)

Zhang2022_7c4_vlsr = []
for i in qvlsr:
    Zhang2022_7c4_vlsr.append(i)

Zhang2022_7c4_vlsr_error = []
for i in qvlsrerror:
    Zhang2022_7c4_vlsr_error.append(i)
    
Zhang2022_7c4_S = []
for i in S:
    Zhang2022_7c4_S.append(i)

Zhang2022_7c4_S_error = []
for i in S_error:
    Zhang2022_7c4_S_error.append(i)

# %%
data_d2 = {"line": [], "epoch": [], "VLSR": [], "VLSR_error": [], "S":[],  "S_error":[]}
data_d2 = pd.DataFrame(data_d2)

lin_53_1 = pd.Series({"line": "(5,3)", "epoch": df.epoch_year[0], "VLSR": df.vlsr_kms[0], "VLSR_error": df.vlsr_kms_error[0], "S": df.S[0],  "S_error":df.S_error[0]}) #blue
lin_53_2 = pd.Series({"line": "(5,3)", "epoch": df.epoch_year[1], "VLSR": df.vlsr_kms[1], "VLSR_error": df.vlsr_kms_error[1], "S": df.S[1],  "S_error":df.S_error[1]}) 
lin_62_1 = pd.Series({"line": "(6,2)", "epoch": df.epoch_year[2], "VLSR": df.vlsr_kms[2], "VLSR_error": df.vlsr_kms_error[2], "S": df.S[2],  "S_error":df.S_error[2]}) #orange
lin_63_1 = pd.Series({"line": "(6,3)", "epoch": df.epoch_year[3], "VLSR": df.vlsr_kms[3], "VLSR_error": df.vlsr_kms_error[3], "S": df.S[3],  "S_error":df.S_error[3]}) #green
lin_63_2 = pd.Series({"line": "(6,3)", "epoch": df.epoch_year[4], "VLSR": df.vlsr_kms[4], "VLSR_error": df.vlsr_kms_error[4], "S": df.S[4],  "S_error":df.S_error[4]}) 
lin_74_1 = pd.Series({"line": "(7,4)", "epoch": df.epoch_year[5], "VLSR": df.vlsr_kms[5], "VLSR_error": df.vlsr_kms_error[5], "S": df.S[5],  "S_error":df.S_error[5]}) #red
lin_75_1 = pd.Series({"line": "(7,5)", "epoch": df.epoch_year[6], "VLSR": df.vlsr_kms[6], "VLSR_error": df.vlsr_kms_error[6], "S": df.S[6],  "S_error":df.S_error[6]}) #purple
lin_98_1 = pd.Series({"line": "(9,8)", "epoch": df.epoch_year[14], "VLSR": df.vlsr_kms[14], "VLSR_error": df.vlsr_kms_error[14], "S": df.S[14],  "S_error":df.S_error[14]}) #brown

lin_53_10 = pd.Series({"line": "(5,3)", "epoch": epoch_2.decimalyear[1], "VLSR": VLSR[1], "VLSR_error": 0.02, "S": S[1] })
lin_62_10 = pd.Series({"line": "(6,2)", "epoch": epoch_2.decimalyear[0], "VLSR": VLSR[0], "VLSR_error": 0.02, "S": S[0]})
lin_63_10 = pd.Series({"line": "(6,3)", "epoch": epoch_2.decimalyear[2], "VLSR": VLSR[2], "VLSR_error": 0.01,"S": S[2]})
lin_74_10 = pd.Series({"line": "(7,4)", "epoch": epoch_2.decimalyear[4], "VLSR": VLSR[4], "VLSR_error": 0.05, "S": S[4]})
lin_75_10 = pd.Series({"line": "(7,5)", "epoch": epoch_2.decimalyear[5], "VLSR": VLSR[5], "VLSR_error": 0.02, "S": S[5]})
lin_98_10 = pd.Series({"line": "(9,8)", "epoch": epoch_2.decimalyear[26], "VLSR": VLSR[26], "VLSR_error": 0.08,"S": S[26]})

lin_53_100 = pd.Series({"line": "(5,3)", "epoch": Zhang2022_5c3_time, "VLSR": Zhang2022_5c3_vlsr, "VLSR_error": Zhang2022_5c3_vlsr_error,})
Zhang2022_5c3_vlsr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /apps/python/3.8/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/1015351716.py in <module>
#      11 lin_98_1 = pd.Series({"line": "(9,8)", "epoch": df.epoch_year[14], "VLSR": df.vlsr_kms[14], "VLSR_error": df.vlsr_kms_error[14], "S": df.S[14],  "S_error":df.S_error[14]}) #brown
#      12
# ...

# %%
lin_76_1 = pd.Series({"line": "(7,6)", "epoch": df.epoch_year[7], "VLSR": df.vlsr_kms[7], "VLSR_error": df.vlsr_kms_error[7], "S": df.S[7],  "S_error":df.S_error[7]}) 
lin_76_2 = pd.Series({"line": "(7,6)", "epoch": df.epoch_year[8], "VLSR": df.vlsr_kms[8], "VLSR_error": df.vlsr_kms_error[8], "S": df.S[8],  "S_error":df.S_error[8]})
lin_76_3 = pd.Series({"line": "(7,6)", "epoch": df.epoch_year[9], "VLSR": df.vlsr_kms[9], "VLSR_error": df.vlsr_kms_error[9], "S": df.S[9],  "S_error":df.S_error[9]})
lin_77_1 = pd.Series({"line": "(7,7)", "epoch": df.epoch_year[10], "VLSR": df.vlsr_kms[10], "VLSR_error": df.vlsr_kms_error[10], "S": df.S[10],  "S_error":df.S_error[10]})
lin_77_2 = pd.Series({"line": "(7,7)", "epoch": df.epoch_year[11], "VLSR": df.vlsr_kms[11], "VLSR_error": df.vlsr_kms_error[11], "S": df.S[11],  "S_error":df.S_error[11]})
lin_77_3 = pd.Series({"line": "(7,7)", "epoch": df.epoch_year[12], "VLSR": df.vlsr_kms[12], "VLSR_error": df.vlsr_kms_error[12], "S": df.S[12],  "S_error":df.S_error[12]})
lin_119_1 = pd.Series({"line": "(11,9)", "epoch": df.epoch_year[15], "VLSR": df.vlsr_kms[15], "VLSR_error": df.vlsr_kms_error[15], "S": df.S[15],  "S_error":df.S_error[15]})

lin_76_10 = pd.Series({"line": "(7,6)", "epoch": epoch_2.decimalyear[9], "VLSR": VLSR[9], "VLSR_error": 0.01, "S": S[9],  "S_error": np.nan})
lin_76_11 = pd.Series({"line": "(7,6)", "epoch": epoch_2.decimalyear[10], "VLSR": VLSR[10], "VLSR_error": 0.02, "S": S[10],  "S_error": np.nan})
lin_77_10 = pd.Series({"line": "(7,7)", "epoch": epoch_2.decimalyear[19], "VLSR": VLSR[19], "VLSR_error": 0.02, "S": S[19],  "S_error": np.nan})
lin_77_11 = pd.Series({"line": "(7,7)", "epoch": epoch_2.decimalyear[20], "VLSR": VLSR[20], "VLSR_error": 0.01, "S": S[20],  "S_error": np.nan})
lin_77_12 = pd.Series({"line": "(7,7)", "epoch": epoch_2.decimalyear[21], "VLSR": VLSR[21], "VLSR_error": 0.05, "S": S[21],  "S_error": np.nan})
lin_77_13 = pd.Series({"line": "(7,7)", "epoch": epoch_2.decimalyear[22], "VLSR": VLSR[22], "VLSR_error": 0.11, "S": S[22],  "S_error": np.nan})
lin_77_14 = pd.Series({"line": "(7,7)", "epoch": epoch_2.decimalyear[23], "VLSR": VLSR[23], "VLSR_error": 0.11, "S": S[23],  "S_error": np.nan})
lin_119_10 = pd.Series({"line": "(11,9)", "epoch": epoch_2.decimalyear[32], "VLSR": VLSR[32], "VLSR_error": 0.01, "S": S[32],  "S_error": np.nan})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /apps/python/3.8/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 9 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/1495104943.py in <module>
#       7 lin_119_1 = pd.Series({"line": "(11,9)", "epoch": df.epoch_year[15], "VLSR": df.vlsr_kms[15], "VLSR_error": df.vlsr_kms_error[15], "S": df.S[15],  "S_error":df.S_error[15]})
#       8
# ...

# %%
data_d2.loc['1'] = lin_53_1
data_d2.loc['2'] = lin_53_2
data_d2.loc['3'] = lin_62_1
data_d2.loc['4'] = lin_63_1
data_d2.loc['5'] = lin_63_2
data_d2.loc['6'] = lin_74_1
data_d2.loc['7'] = lin_75_1
data_d2.loc['8'] = lin_98_1
data_d2.loc['9'] = lin_53_10
data_d2.loc['11'] = lin_62_10
data_d2.loc['12'] = lin_63_10
data_d2.loc['14'] = lin_74_10
data_d2.loc['15'] = lin_75_10
data_d2.loc['16'] = lin_98_10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/1394469765.py in <module>
#       7 data_d2.loc['7'] = lin_75_1
#       8 data_d2.loc['8'] = lin_98_1
# ----> 9 data_d2.loc['9'] = lin_53_10
#      10 data_d2.loc['11'] = lin_62_10
#      11 data_d2.loc['12'] = lin_63_10
#
# NameError: name 'lin_53_10' is not defined

# %%
##

def extract_list(str_num,line,zhang_time, zhang_vlsr, zhang_vlsr_error, zhang_S, zhang_S_error):
    for i,j,k,l,s in zip(zhang_time, zhang_vlsr, zhang_vlsr_error, zhang_S, zhang_S_error):
        data_d2.loc[str(str_num)] = pd.Series({"line":line, "epoch": i, "VLSR": j, "VLSR_error": k, "S":l,  "S_error":s})
        str_num += 1
        
extract_list(17,'(5,3)',Zhang2022_5c3_time, Zhang2022_5c3_vlsr, Zhang2022_5c3_vlsr_error, Zhang2022_5c3_S, Zhang2022_5c3_S_error)
extract_list(22,'(6,2)',Zhang2022_6c2_time, Zhang2022_6c2_vlsr, Zhang2022_6c2_vlsr_error, Zhang2022_6c2_S, Zhang2022_6c2_S_error)
extract_list(26,'(6,3)',Zhang2022_6c3_time, Zhang2022_6c3_vlsr, Zhang2022_6c3_vlsr_error, Zhang2022_6c3_S, Zhang2022_6c3_S_error)
extract_list(33,'(7,5)',Zhang2022_7c5_time, Zhang2022_7c5_vlsr, Zhang2022_7c5_vlsr_error, Zhang2022_7c5_S, Zhang2022_7c5_S_error)
extract_list(40,'(9,8)',Zhang2022_9c8_time, Zhang2022_9c8_vlsr, Zhang2022_9c8_vlsr_error, Zhang2022_9c8_S, Zhang2022_9c8_S_error)
extract_list(45,'(7,6)',Zhang2022_7c6_time, Zhang2022_7c6_vlsr, Zhang2022_7c6_vlsr_error, Zhang2022_7c6_S, Zhang2022_7c6_S_error)
extract_list(52,'(7,7)',Zhang2022_7c7_time, Zhang2022_7c7_vlsr, Zhang2022_7c7_vlsr_error, Zhang2022_7c7_S, Zhang2022_7c7_S_error)
extract_list(57,'(11,9)',Zhang2022_11c9_time, Zhang2022_11c9_vlsr, Zhang2022_11c9_vlsr_error, Zhang2022_11c9_S, Zhang2022_11c9_S_error)

# %%
data_d2.loc['59'] = lin_76_1
data_d2.loc['60'] = lin_76_2
data_d2.loc['61'] = lin_76_3
data_d2.loc['62'] = lin_77_1
data_d2.loc['63'] = lin_77_2
data_d2.loc['64'] = lin_77_3
data_d2.loc['65'] = lin_119_1
data_d2.loc['66'] = lin_76_10
data_d2.loc['67'] = lin_76_11
data_d2.loc['68'] = lin_77_10
data_d2.loc['69'] = lin_77_11
data_d2.loc['70'] = lin_77_12
data_d2.loc['71'] = lin_77_13
data_d2.loc['72'] = lin_77_14
data_d2.loc['73'] = lin_119_10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/2512536268.py in <module>
#       6 data_d2.loc['64'] = lin_77_3
#       7 data_d2.loc['65'] = lin_119_1
# ----> 8 data_d2.loc['66'] = lin_76_10
#       9 data_d2.loc['67'] = lin_76_11
#      10 data_d2.loc['68'] = lin_77_10
#
# NameError: name 'lin_76_10' is not defined

# %%
all_53 = data_d2.loc[data_d2['line'] == '(5,3)']
all_62 = data_d2.loc[data_d2['line'] == '(6,2)']
all_63 = data_d2.loc[data_d2['line'] == '(6,3)']
all_74 = data_d2.loc[data_d2['line'] == '(7,4)']
all_75 = data_d2.loc[data_d2['line'] == '(7,5)']
all_98 = data_d2.loc[data_d2['line'] == '(9,8)']
all_76 = data_d2.loc[data_d2['line'] == '(7,6)']
all_77 = data_d2.loc[data_d2['line'] == '(7,7)']
all_119 = data_d2.loc[data_d2['line'] == '(11,9)']
all_119
# Out:
#       line        epoch       VLSR VLSR_error      S S_error
# 57  (11,9)  2020.248634      47.35       0.04    0.3    0.04
# 58  (11,9)  2020.248634      62.45       0.19   0.15    0.04
# 65  (11,9)  2019.583562  47.506972      0.007  0.416   0.006

# %%
plot_62 = all_62.sort_values("epoch")
plot_62 = plot_62.drop('24')
plot_62 = plot_62.drop('25')

plot_62
# Out:
#      line        epoch       VLSR VLSR_error      S S_error
# 3   (6,2)  2019.583562  53.895252      0.033  0.039   0.002
# 22  (6,2)  2020.019126      54.11        NaN    0.1     NaN
# 23  (6,2)  2020.204918      54.11       0.09   0.08    0.02

# %%
plot_53 = all_53.sort_values("epoch")
plot_53 = plot_53.drop('2')
plot_53 = plot_53.drop('19')
plot_53 = plot_53.drop('20')
plot_53 = plot_53.drop('21')
plot_53 = plot_53.drop('17')
plot_53 = plot_53.drop('18')
plot_53
# Out:
#     line        epoch       VLSR VLSR_error     S S_error
# 1  (5,3)  2019.583562  55.985888      0.004  0.46   0.006

# %%
plot_63 = all_63.sort_values("epoch")
plot_63 = plot_63.drop('5')
plot_63 = plot_63.drop('26')
plot_63 = plot_63.drop('28')
plot_63 = plot_63.drop('30')
plot_63 = plot_63.drop('32')
plot_63
# Out:
#      line        epoch       VLSR VLSR_error       S S_error
# 4   (6,3)  2019.583562  55.201461      0.003  0.5065   0.005
# 27  (6,3)  2020.019126      55.88       0.02    1.13     0.1
# 29  (6,3)  2020.204918      55.82       0.01    3.05     0.1
# 31  (6,3)  2020.248634      55.92       0.01    3.92    0.25

# %%
plot_74 = all_74
plot_74
# Out:
#     line        epoch       VLSR VLSR_error       S S_error
# 6  (7,4)  2019.583562  54.051188      0.203  0.0468   0.005

# %%
plot_75 = all_75.sort_values("epoch")
plot_75 = plot_75.drop('33')
plot_75 = plot_75.drop('34')
plot_75 = plot_75.drop('35')
plot_75 = plot_75.drop('36')
plot_75 = plot_75.drop('37')
plot_75 = plot_75.drop('39')
plot_75
# Out:
#      line        epoch       VLSR VLSR_error      S S_error
# 7   (7,5)  2019.583562  53.748378      0.014  2.458   0.023
# 38  (7,5)  2020.019126      48.06       0.02   0.61    0.04

# %%
plot_98 = all_98.sort_values("epoch")
plot_98 = plot_98.drop("44")
plot_98
# Out:
#      line        epoch       VLSR VLSR_error       S S_error
# 8   (9,8)  2019.583562  54.123012       0.01  0.1758   0.006
# 40  (9,8)  2020.019126       54.5       0.08    0.19    0.06
# 41  (9,8)  2020.215847      54.45       0.02    0.27    0.03
# 42  (9,8)  2020.248634      54.45        NaN    0.07     NaN
# 43  (9,8)  2020.265027      54.45        NaN    0.25     NaN

# %%
plot_76 = all_76.sort_values("epoch")
plot_76 = plot_76.drop("59")
plot_76 = plot_76.drop("60")
plot_76 = plot_76.drop("46")
plot_76 = plot_76.drop("48")
plot_76 = plot_76.drop("50")
plot_76
# Out:
#      line        epoch       VLSR VLSR_error       S S_error
# 61  (7,6)  2019.583562  47.600759      0.008  0.3645   0.006
# 45  (7,6)  2020.019126      48.06       0.02    0.61    0.04
# 47  (7,6)  2020.215847      48.15       0.03    0.49    0.03
# 49  (7,6)  2020.248634      48.11       0.07    0.31    0.05
# 51  (7,6)  2020.265027      48.11        NaN    0.12     NaN

# %%
plot_77 = all_77.sort_values("epoch")
plot_77 = plot_77.drop("68")
plot_77 = plot_77.drop("72")
plot_77 = plot_77.drop("62")
plot_77 = plot_77.drop("64")
plot_77
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/3007983669.py in <module>
#       1 plot_77 = all_77.sort_values("epoch")
# ----> 2 plot_77 = plot_77.drop("68")
#       3 plot_77 = plot_77.drop("72")
#       4 plot_77 = plot_77.drop("62")
#       5 plot_77 = plot_77.drop("64")
#
# /apps/python/3.8/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /apps/python/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4954                 weight  1.0     0.8
#    4955         """
# -> 4956         return super().drop(
#    4957             labels=labels,
# ...

# %%
plot_119 = all_119.sort_values("epoch")
plot_119 = plot_119.drop("58")
plot_119
# Out:
#       line        epoch       VLSR VLSR_error      S S_error
# 65  (11,9)  2019.583562  47.506972      0.007  0.416   0.006
# 57  (11,9)  2020.248634      47.35       0.04    0.3    0.04

# %%
#Slope

def slope(final, initial, final_t, initial_t):
    return (final - initial)/(final_t - initial_t)

average = []
def average_array(epoch,data):
    for i in range(len(data)-1):
        print(i)
        average.append(slope(data[i], data[i-1], epoch[i], epoch[i-1]))
        
average_array(plot_53['epoch'],plot_53['VLSR'])
average_array(plot_62['epoch'],plot_62['VLSR'])
average_array(plot_63['epoch'],plot_63['VLSR'])
average_array(plot_74['epoch'],plot_74['VLSR'])
average_array(plot_75['epoch'],plot_75['VLSR'])
average_array(plot_75['epoch'],plot_75['VLSR'])
average_array(plot_98['epoch'],plot_98['VLSR'])
mean_slopes = np.mean(average)
std_slopes = np.std(average)
slope_53 = (plot_53['VLSR'][1] - plot_53['VLSR'][0])/(plot_53['epoch'][1] - plot_53['epoch'][0])
slope_62 = (plot_62['VLSR'][1] - plot_62['VLSR'][0])/(plot_62['epoch'][1] - plot_62['epoch'][0])
slope_63 = (plot_63['VLSR'][1] - plot_63['VLSR'][0])/(plot_63['epoch'][1] - plot_63['epoch'][0])
slope_74 = (plot_74['VLSR'][1] - plot_74['VLSR'][0])/(plot_74['epoch'][1] - plot_53['epoch'][0])
slope_53 = (plot_53['VLSR'][1] - plot_53['VLSR'][0])/(plot_53['epoch'][1] - plot_53['epoch'][0])
# Out:
# 0
# 1
# 0
# 1
# 2
# 0
# 0
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/1077451985.py in <module>
#      19 mean_slopes = np.mean(average)
#      20 std_slopes = np.std(average)
# ---> 21 slope_53 = (plot_53['VLSR'][1] - plot_53['VLSR'][0])/(plot_53['epoch'][1] - plot_53['epoch'][0])
#      22 slope_62 = (plot_62['VLSR'][1] - plot_62['VLSR'][0])/(plot_62['epoch'][1] - plot_62['epoch'][0])
#      23 slope_63 = (plot_63['VLSR'][1] - plot_63['VLSR'][0])/(plot_63['epoch'][1] - plot_63['epoch'][0])
#
# /apps/python/3.8/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     954
#     955         if is_integer(key) and self.index._should_fallback_to_positional:
# --> 956             return self._values[key]
#     957
#     958         elif key_is_scalar:
#
# ...

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7
ax.errorbar(all_76['epoch'], all_76['VLSR'], yerr=all_76['VLSR_error'], color="tab:cyan", marker = "*",ls='none',elinewidth=x,capsize=y,label='(7,6)')
ax.errorbar(all_77['epoch'], all_77['VLSR'], yerr=all_77['VLSR_error'], color="tab:pink", marker = "x",ls='none',elinewidth=x,capsize=y,label='(7,7)')
ax.errorbar(all_119['epoch'], all_119['VLSR'], yerr=all_119['VLSR_error'], color="tab:olive", marker = "8",ls='none',elinewidth=x,capsize=y,label='(11,9)')

ax.plot(plot_76['epoch'], plot_76['VLSR'],color="tab:cyan")
ax.plot(plot_77['epoch'], plot_77['VLSR'],color="tab:pink")
ax.plot(plot_119['epoch'], plot_119['VLSR'],color="tab:olive")


def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []
gogo(plot_76['VLSR'],num)
gogo(plot_77['VLSR'],num)
gogo(plot_119['VLSR'],num)

num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

#ax.text(0.1,0.05,'%(a)a ±%(b)a km s$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopes,2),'b':round(std_slopes,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"CA3",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,45,52])
all_119
# Out:
#       line        epoch       VLSR VLSR_error      S S_error
# 57  (11,9)  2020.248634      47.35       0.04    0.3    0.04
# 58  (11,9)  2020.248634      62.45       0.19   0.15    0.04
# 65  (11,9)  2019.583562  47.506972      0.007  0.416   0.006

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7
ax.errorbar(all_53['epoch'], all_53['VLSR'], yerr=all_53['VLSR_error'], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,label='(5,3)')
ax.errorbar(all_62['epoch'], all_62['VLSR'], yerr=all_62['VLSR_error'], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,label='(6,2)')
ax.errorbar(all_63['epoch'], all_63['VLSR'], yerr=all_63['VLSR_error'], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,label='(6,3)')
ax.errorbar(all_74['epoch'], all_74['VLSR'], yerr=all_74['VLSR_error'], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,label='(7,4)')
ax.errorbar(all_75['epoch'], all_75['VLSR'], yerr=all_75['VLSR_error'], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,label='(7,5)')
ax.errorbar(all_98['epoch'], all_98['VLSR'], yerr=all_98['VLSR_error'], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,label='(9,8)')

ax.plot(plot_53['epoch'], plot_53['VLSR'],color="tab:blue")
ax.plot(plot_62['epoch'], plot_62['VLSR'],color="tab:orange")
ax.plot(plot_63['epoch'], plot_63['VLSR'],color="tab:green")
ax.plot(plot_74['epoch'], plot_74['VLSR'],color="tab:red")
ax.plot(plot_75['epoch'], plot_75['VLSR'],color="tab:purple")
ax.plot(plot_98['epoch'], plot_98['VLSR'],color="tab:brown")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []
gogo(plot_53['VLSR'],num)
gogo(plot_62['VLSR'],num)
gogo(plot_63['VLSR'],num)
gogo(plot_74['VLSR'],num)
gogo(plot_75['VLSR'],num)
gogo(plot_98['VLSR'],num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

#ax.text(0.1,0.05,'%(a)a ±%(b)a km s$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopes,2),'b':round(std_slopes,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,53.5,57.2])
# Out:
# (2008.0, 2021.0, 53.5, 57.2)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7
ax.errorbar(all_53['epoch'], all_53['VLSR'], yerr=all_53['VLSR_error'], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,label='(5,3)')
ax.errorbar(all_62['epoch'], all_62['VLSR'], yerr=all_62['VLSR_error'], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,label='(6,2)')
ax.errorbar(all_63['epoch'], all_63['VLSR'], yerr=all_63['VLSR_error'], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,label='(6,3)')
ax.errorbar(all_74['epoch'], all_74['VLSR'], yerr=all_74['VLSR_error'], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,label='(7,4)')
ax.errorbar(all_75['epoch'], all_75['VLSR'], yerr=all_75['VLSR_error'], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,label='(7,5)')
ax.errorbar(all_98['epoch'], all_98['VLSR'], yerr=all_98['VLSR_error'], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,label='(9,8)')

ax.plot(plot_53['epoch'], plot_53['VLSR'],color="tab:blue")
ax.plot(plot_62['epoch'], plot_62['VLSR'],color="tab:orange")
ax.plot(plot_63['epoch'], plot_63['VLSR'],color="tab:green")
ax.plot(plot_74['epoch'], plot_74['VLSR'],color="tab:red")
ax.plot(plot_75['epoch'], plot_75['VLSR'],color="tab:purple")
ax.plot(plot_98['epoch'], plot_98['VLSR'],color="tab:brown")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []
gogo(plot_53['VLSR'],num)
gogo(plot_62['VLSR'],num)
gogo(plot_63['VLSR'],num)
gogo(plot_74['VLSR'],num)
gogo(plot_75['VLSR'],num)
gogo(plot_98['VLSR'],num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

#ax.text(0.1,0.05,'%(a)a ±%(b)a km s$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopes,2),'b':round(std_slopes,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,46.5,58.2])
# Out:
# (2008.0, 2021.0, 46.5, 58.2)

# %%
average = []
average_array(plot_53['epoch'],plot_53['S'])
average_array(plot_62['epoch'],plot_62['S'])
average_array(plot_63['epoch'],plot_63['S'])
average_array(plot_74['epoch'],plot_74['S'])
average_array(plot_75['epoch'],plot_75['S'])
average_array(plot_75['epoch'],plot_75['S'])
average_array(plot_98['epoch'],plot_98['S'])
mean_slopesS = np.mean(average)
std_slopesS = np.std(average)
slope_53S = (plot_53['S'][1] - plot_53['S'][0])/(plot_53['S'][1] - plot_53['S'][0])
slope_62S = (plot_62['S'][1] - plot_62['S'][0])/(plot_62['S'][1] - plot_62['S'][0])
slope_63S = (plot_63['S'][1] - plot_63['S'][0])/(plot_63['S'][1] - plot_63['S'][0])
slope_74S = (plot_74['S'][1] - plot_74['S'][0])/(plot_74['S'][1] - plot_53['S'][0])
slope_53S = (plot_53['S'][1] - plot_53['S'][0])/(plot_53['S'][1] - plot_53['S'][0])
# Out:
# 0
# 1
# 0
# 1
# 2
# 0
# 0
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /scratch/local/16076467/ipykernel_1603870/3118832677.py in <module>
#       9 mean_slopesS = np.mean(average)
#      10 std_slopesS = np.std(average)
# ---> 11 slope_53S = (plot_53['S'][1] - plot_53['S'][0])/(plot_53['S'][1] - plot_53['S'][0])
#      12 slope_62S = (plot_62['S'][1] - plot_62['S'][0])/(plot_62['S'][1] - plot_62['S'][0])
#      13 slope_63S = (plot_63['S'][1] - plot_63['S'][0])/(plot_63['S'][1] - plot_63['S'][0])
#
# /apps/python/3.8/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     954
#     955         if is_integer(key) and self.index._should_fallback_to_positional:
# --> 956             return self._values[key]
#     957
#     958         elif key_is_scalar:
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7
ax.errorbar(all_76['epoch'], all_76['S'], yerr=all_76['S_error'], color="tab:cyan", marker = "*",ls='none',elinewidth=x,capsize=y,label='(7,6)')
ax.errorbar(all_77['epoch'], all_77['S'], yerr=all_77['S_error'], color="tab:pink", marker = "x",ls='none',elinewidth=x,capsize=y,label='(7,7)')
ax.errorbar(all_119['epoch'], all_119['S'], yerr=all_119['S_error'], color="tab:olive", marker = "8",ls='none',elinewidth=x,capsize=y,label='(11,9)')

ax.plot(plot_76['epoch'], plot_76['S'],color="tab:cyan")
ax.plot(plot_77['epoch'], plot_77['S'],color="tab:pink")
ax.plot(plot_119['epoch'], plot_119['S'],color="tab:olive")


def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []
gogo(plot_76['S'],num)
gogo(plot_77['S'],num)
gogo(plot_119['S'],num)

num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

#ax.text(0.4,0.05,'%(a)a ±%(b)a km s$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopes,2),'b':round(std_slopes,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.15,.9,"CA3",fontsize = 16, weight='bold',transform=ax.transAxes)
_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=1,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2008,2021,-.7,2.7])
all_77
# Out:
#      line        epoch       VLSR  VLSR_error       S  S_error
# 52  (7,7)  2020.248634        NaN         NaN     NaN      NaN
# 53  (7,7)  2020.199454        NaN         NaN     NaN      NaN
# 54  (7,7)  2020.204918        NaN         NaN     NaN      NaN
# 55  (7,7)  2020.215847        NaN         NaN     NaN      NaN
# 56  (7,7)  2020.248634        NaN         NaN     NaN      NaN
# 62  (7,7)  2019.583562  49.920366       0.115  0.0433    0.006
# 63  (7,7)  2019.583562  47.588728       0.007  0.5501    0.004
# 64  (7,7)  2019.583562  46.422910       0.022  0.2278    0.006
# 68  (7,7)  2008.808743  45.600000       0.020  1.7000      NaN
# 69  (7,7)  2008.808743  46.080000       0.010  2.4800      NaN
# 70  (7,7)  2008.814208  45.660000       0.050  2.2700      NaN
# 71  (7,7)  2012.256831  47.290000       0.110  0.2000      NaN
# 72  (7,7)  2012.256831  49.920000       0.110  0.1800      NaN

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7
ax.errorbar(all_53['epoch'], all_53['S'], yerr=all_53['S'], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,label='(5,3)')
ax.errorbar(all_62['epoch'], all_62['S'], yerr=all_62['S_error'], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,label='(6,2)')
ax.errorbar(all_63['epoch'], all_63['S'], yerr=all_63['S_error'], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,label='(6,3)')
ax.errorbar(all_74['epoch'], all_74['S'], yerr=all_74['S_error'], color="tab:red", marker = "H",ls='none',elinewidth=x,capsize=y,label='(7,4)')
ax.errorbar(all_75['epoch'], all_75['S'], yerr=all_75['S_error'], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,label='(7,5)')
ax.errorbar(all_98['epoch'], all_98['S'], yerr=all_98['S_error'], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,label='(9,8)')

ax.plot(plot_53['epoch'], plot_53['S'],color="tab:blue")
ax.plot(plot_62['epoch'], plot_62['S'],color="tab:orange")
ax.plot(plot_63['epoch'], plot_63['S'],color="tab:green")
ax.plot(plot_74['epoch'], plot_74['S'],color="tab:red")
ax.plot(plot_75['epoch'], plot_75['S'],color="tab:purple")
ax.plot(plot_98['epoch'], plot_98['S'],color="tab:brown")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []
gogo(plot_53['S'],num)
gogo(plot_62['S'],num)
gogo(plot_63['S'],num)
gogo(plot_74['S'],num)
gogo(plot_75['S'],num)
gogo(plot_98['S'],num)
print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

#ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2010,2021,-0.2,2])
# Out:
# [0.3, 0.46, 0.22, 0.039, 0.1, 0.08, 0.35, 0.5065, 1.13, 3.05, 3.92, 0.0468, 0.09, 3.1, 2.458, 0.61, 0.22, 0.1758, 0.19, 0.27, 0.07, 0.25]
# (2010.0, 2021.0, -0.2, 2.0)

# %% [markdown]
# #### (6,3) maser varability

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_63['epoch'], all_63['S'], yerr=all_63['S_error'], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,label='(6,3)')
ax.plot(plot_63['epoch'], plot_63['S'],color="tab:green")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_63['S'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,-0.5,4.7])
# Out:
# [0.35, 0.5065, 1.13, 3.05, 3.92]
# (2011.5, 2021.0, -0.5, 4.7)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_63['epoch'], all_63['VLSR'], yerr=all_63['VLSR_error'], color="tab:green", marker = "p",ls='none',elinewidth=x,capsize=y,label='(6,3)')
ax.plot(plot_63['epoch'], plot_63['VLSR'],color="tab:green")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_63['VLSR'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011,2021,54,58])
# Out:
# [56.5, 55.2014609413, 55.88, 55.82, 55.92]
# (2011.0, 2021.0, 54.0, 58.0)

# %% [markdown]
# #### (5,3) maser variabilty

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_53['epoch'], all_53['S'], yerr=all_53['S_error'], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,label='(5,3)')
ax.plot(plot_53['epoch'], plot_53['S'],color="tab:blue")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_63['S'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,0,.6])
# Out:
# [0.35, 0.5065, 1.13, 3.05, 3.92]
# (2011.5, 2021.0, 0.0, 0.6)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_53['epoch'], all_53['VLSR'], yerr=all_53['VLSR_error'], color="tab:blue", marker = "^",ls='none',elinewidth=x,capsize=y,label='(5,3)')
ax.plot(plot_53['epoch'], plot_53['VLSR'],color="tab:blue")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_63['VLSR'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011,2021,54,58])
# Out:
# [56.5, 55.2014609413, 55.88, 55.82, 55.92]
# (2011.0, 2021.0, 54.0, 58.0)

# %% [markdown]
# #### (6,2) maser varability

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_62['epoch'], all_62['S'], yerr=all_62['S_error'], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,label='(6,2)')
ax.plot(plot_62['epoch'], plot_62['S'],color="tab:orange")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_62['S'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,0,.3])
# Out:
# [0.22, 0.039, 0.1, 0.08]
# (2011.5, 2021.0, 0.0, 0.3)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_62['epoch'], all_62['VLSR'], yerr=all_62['VLSR_error'], color="tab:orange", marker = "s",ls='none',elinewidth=x,capsize=y,label='(6,2)')
ax.plot(plot_62['epoch'], plot_62['VLSR'],color="tab:orange")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_62['VLSR'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011,2021,53.7,54.6])
# Out:
# [54.39, 53.895251944, 54.11, 54.11]
# (2011.0, 2021.0, 53.7, 54.6)

# %% [markdown]
# #### (9,8) maser variabilty

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_98['epoch'], all_98['S'], yerr=all_98['S_error'], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,label='(9,8)')
ax.plot(plot_98['epoch'], plot_98['S'],color="tab:brown")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_98['S'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,0,.4])
# Out:
# [0.22, 0.1758, 0.19, 0.27, 0.07, 0.25]
# (2011.5, 2021.0, 0.0, 0.4)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_98['epoch'], all_98['VLSR'], yerr=all_98['VLSR_error'], color="tab:brown", marker = "v",ls='none',elinewidth=x,capsize=y,label='(9,8)')
ax.plot(plot_98['epoch'], plot_98['VLSR'],color="tab:brown")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_98['VLSR'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011,2021,54,55])
# Out:
# [54.72, 54.1230120548, 54.5, 54.45, 54.45, 54.45]
# (2011.0, 2021.0, 54.0, 55.0)

# %% [markdown]
# #### (7,5) maser variabilty

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_75['epoch'], all_75['S'], yerr=all_75['S_error'], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,label='(7,5)')
ax.plot(plot_75['epoch'], plot_75['S'],color="tab:purple")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_75['S'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$S$ (Jy beam$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,0,4])
# Out:
# [3.1, 2.458, 0.61]
# (2011.5, 2021.0, 0.0, 4.0)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax = plt.subplot()
x=0.6
y=7

ax.errorbar(all_75['epoch'], all_75['VLSR'], yerr=all_75['VLSR_error'], color="tab:purple", marker = "+",ls='none',elinewidth=x,capsize=y,label='(7,5)')
ax.plot(plot_75['epoch'], plot_75['VLSR'],color="tab:purple")

def gogo(plot,num):
    array = plot.to_numpy()
    for i in array:
        num.append(i)

num = []

gogo(plot_75['VLSR'],num)

print(num)
num = np.array(num)
num = num[np.logical_not(np.isnan(num))]
num_std = np.std(num)

ax.text(0.1,.04,'%(a)a ±%(b)a Jy beam$^{-1}$ yr$^{-1}$' % {'a':round(mean_slopesS,2),'b':round(std_slopesS,2)}, fontsize = 16, transform=ax.transAxes)
ax.text(0.8,.9,"d2",fontsize = 16, weight='bold',transform=ax.transAxes)

_ = ax.set_xlabel(f"Epoch", fontsize = 18)    
_ = ax.set_ylabel("$V_{LSR}$ (km s$^{-1}$)", fontsize = 18)
tick_fontsize = 16
ax.legend(title="NH$_3$ (J,K)",fontsize = 14, loc=2,)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.axis([2011.5,2021,44,59])
# Out:
# [54.44, 53.7483780612, 48.06]
# (2011.5, 2021.0, 44.0, 59.0)
